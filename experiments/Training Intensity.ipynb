# %%
import numpy as np
from collections import defaultdict

import torch
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as transforms

import torch.nn as nn
import torch.optim as optim
from tqdm import tqdm

import pandas as pd
import os

# %%
# ==============================
# Dirichlet non-IID splitter
# ==============================
def dirichlet_split_noniid(dataset, num_clients, alpha, seed=42):
    """
    Dirichlet label-distribution-based non-IID split.

    New semantics:
      - alpha = 0   -> IID split (random, equal-size).
      - alpha > 0   -> non-IID; larger alpha => more skewed (more non-IID).

    Returns:
        dict: {client_id: np.ndarray of indices}
    """
    np.random.seed(seed)

    n_samples = len(dataset)

    # ----- Special case: alpha = 0 => IID -----
    if alpha == 0:
        all_indices = np.random.permutation(n_samples)
        splits = np.array_split(all_indices, num_clients)
        client_indices = {
            cid: splits[cid] for cid in range(num_clients)
        }
        return client_indices

    # ----- alpha > 0 => Dirichlet-based non-IID -----
    # Map user alpha to Dirichlet concentration:
    # larger user alpha -> smaller conc -> more non-IID
    dirichlet_conc = 1.0 / alpha
    # (optional: clip to avoid extreme numerical issues)
    dirichlet_conc = float(np.clip(dirichlet_conc, 1e-3, 1e3))

    # Get labels generically
    if hasattr(dataset, "targets"):
        labels = np.array(dataset.targets)
    elif hasattr(dataset, "labels"):
        labels = np.array(dataset.labels)
    else:
        labels = np.array([dataset[i][1] for i in range(n_samples)])

    num_classes = int(labels.max()) + 1
    client_indices = defaultdict(list)

    # For each class, sample Dirichlet over clients
    for c in range(num_classes):
        class_idx = np.where(labels == c)[0]
        if len(class_idx) == 0:
            continue
        np.random.shuffle(class_idx)

        # Dirichlet proportions for this class across clients
        proportions = np.random.dirichlet(
            dirichlet_conc * np.ones(num_clients)
        )

        # Convert proportions to index splits
        split_points = (np.cumsum(proportions) * len(class_idx)).astype(int)
        class_split = np.split(class_idx, split_points[:-1])

        for client_id, idx in enumerate(class_split):
            client_indices[client_id].extend(idx.tolist())

    # Shuffle indices inside each client
    for client_id in range(num_clients):
        idx = np.array(client_indices[client_id], dtype=int)
        np.random.shuffle(idx)
        client_indices[client_id] = idx

    return client_indices


# ==============================
# CIFAR-10 + per-client loaders
# ==============================
def get_cifar10_dirichlet_clients(
    data_root="./data",
    num_clients=10,
    alpha=0.5,
    batch_size=64,
    seed=42,
):
    # 1) CIFAR-10 transforms
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=(0.4914, 0.4822, 0.4465),
            std=(0.2023, 0.1994, 0.2010),
        ),
    ])

    # 2) Load CIFAR-10 train set
    trainset = torchvision.datasets.CIFAR10(
        root=data_root,
        train=True,
        download=True,
        transform=transform_train,
    )

    # 3) Get Dirichlet split indices per client
    client_idcs = dirichlet_split_noniid(
        dataset=trainset,
        num_clients=num_clients,
        alpha=alpha,
        seed=seed,
    )

    # 4) Wrap each client’s indices as a Subset + DataLoader
    client_loaders = {}
    for cid, idxs in client_idcs.items():
        subset = Subset(trainset, idxs)
        loader = DataLoader(
            subset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=2,
            pin_memory=True,
        )
        client_loaders[cid] = loader

    return trainset, client_idcs, client_loaders


# ==============================
# CIFAR-100 + per-client loaders
# ==============================
def get_cifar100_dirichlet_clients(
    data_root="./data",
    num_clients=10,
    alpha=0.5,
    batch_size=64,
    seed=42,
):
    # 1) CIFAR-100 transforms (same as CIFAR-10 usually)
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=(0.5071, 0.4867, 0.4408),
            std=(0.2675, 0.2565, 0.2761),
        ),
    ])

    # 2) Load CIFAR-100 train set
    trainset = torchvision.datasets.CIFAR100(
        root=data_root,
        train=True,
        download=True,
        transform=transform_train,
    )

    # 3) Get Dirichlet split indices per client
    client_idcs = dirichlet_split_noniid(
        dataset=trainset,
        num_clients=num_clients,
        alpha=alpha,
        seed=seed,
    )

    # 4) Wrap each client’s indices as a Subset + DataLoader
    client_loaders = {}
    for cid, idxs in client_idcs.items():
        subset = Subset(trainset, idxs)
        loader = DataLoader(
            subset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=2,
            pin_memory=True,
        )
        client_loaders[cid] = loader

    return trainset, client_idcs, client_loaders

# =====================================
# Shakespeare + per-client loaders
# =====================================
def get_shakespeare_dirichlet_clients(
    dataset,
    num_clients=10,
    alpha=0.5,
    batch_size=32,
    seed=42,
):
    """
    dataset: a PyTorch Dataset for Shakespeare samples.
             Must expose labels via .targets/.labels or via dataset[i] -> (x, y).
    """
    # 1) Get Dirichlet split indices per client
    client_idcs = dirichlet_split_noniid(
        dataset=dataset,
        num_clients=num_clients,
        alpha=alpha,
        seed=seed,
    )

    # 2) Wrap each client’s indices as a Subset + DataLoader
    client_loaders = {}
    for cid, idxs in client_idcs.items():
        subset = Subset(dataset, idxs)
        loader = DataLoader(
            subset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=2,
            pin_memory=True,
        )
        client_loaders[cid] = loader

    return dataset, client_idcs, client_loaders

# %%
# ==============================
# Example usage
# ==============================
if __name__ == "__main__":
    NUM_CLIENTS = 10
    ALPHA = 5  # smaller => more non-IID

    trainset, client_idcs, client_loaders = get_cifar10_dirichlet_clients(
        data_root="./data",
        num_clients=NUM_CLIENTS,
        alpha=ALPHA,
        batch_size=64,
        seed=123,
    )

    # Quick sanity check: print per-client sizes
    for cid, idxs in client_idcs.items():
        print(f"Client {cid}: {len(idxs)} samples")

    for i in range(NUM_CLIENTS):
      # Optional: check label distribution for a client
      labels = np.array(trainset.targets)
      cid = i
      client_labels = labels[client_idcs[cid]]
      print(f"Client {cid} label histogram:")
      print(np.bincount(client_labels, minlength=10))
# Out:
# 100%|██████████| 170M/170M [00:19<00:00, 8.67MB/s]
# Client 0: 1580 samples
# Client 1: 3948 samples
# Client 2: 4833 samples
# Client 3: 4475 samples
# Client 4: 7366 samples
# Client 5: 6468 samples
# Client 6: 1431 samples
# Client 7: 8291 samples
# Client 8: 4917 samples
# Client 9: 6691 samples
# Client 0 label histogram:
# [ 55   2   3 493 215   6  13 793   0   0]
# Client 1 label histogram:
# [ 543    0 1151  166  399    0    1    0 1221  467]
# Client 2 label histogram:
# [   1   83 1311 1217  580 1629    0    0   11    1]
# Client 3 label histogram:
# [   2    2    0 2610    0    0 1827    0    1   33]
# Client 4 label histogram:
# [2682    0 1413    0   22 3055   81   22    0   91]
# Client 5 label histogram:
# [ 219    0    0  408 1593    0 1126  551 1805  766]
# Client 6 label histogram:
# [  0   0 727   0   1 244 183   8 261   7]
# Client 7 label histogram:
# [1497  525    0    3 2171    4 1583  336  214 1958]
# Client 8 label histogram:
# [   0 4318   98   60   14    0  185    0  231   11]
# Client 9 label histogram:
# [   1   70  297   43    5   62    1 3290 1256 1666]

# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
import torch.nn as nn
import torch.optim as optim
import torchvision
import pandas as pd
import os
from datetime import datetime
from collections import defaultdict

# %%
import numpy as np
from collections import defaultdict
import torch
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import os
from datetime import datetime

# ----------------------------
# Parameters
# ----------------------------
NUM_CLIENTS = len(client_idcs)
TEST_RATIO = 0.05
TRAIN_BATCH = 16
TEST_BATCH = 32
ROUNDS = 100
LOCAL_EPOCHS = 0.01        # fractional epoch (<1) or integer (>=1)
LR = 1e-3
SEED = 123
AUTOSAVE_PATH = "results_cifar10_alpha5_epoch_0_01_new.csv"
os.makedirs("results", exist_ok=True)

np.random.seed(SEED)
torch.manual_seed(SEED)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------------------
# Model & Loss
# ----------------------------
def get_model(num_classes=10):
    model = torchvision.models.resnet18(weights=None)
    model.fc = nn.Linear(model.fc.in_features, num_classes)
    return model.to(device)

criterion = nn.CrossEntropyLoss()

# ----------------------------
# Split train/test per client (95/5)
# ----------------------------
client_train_idx = {}
client_test_idx = {}
client_train_loaders = {}
client_test_loaders = {}
split_info = {}

for cid, idxs in client_idcs.items():
    idxs = np.array(idxs)
    np.random.shuffle(idxs)
    n = len(idxs)
    n_test = max(1, int(TEST_RATIO * n))
    train_idx = idxs[:-n_test]
    test_idx = idxs[-n_test:]

    client_train_idx[cid] = train_idx.tolist()
    client_test_idx[cid] = test_idx.tolist()
    split_info[cid] = (len(train_idx), len(test_idx))

    client_train_loaders[cid] = DataLoader(
        Subset(trainset, train_idx),
        batch_size=TRAIN_BATCH,
        shuffle=True,
        drop_last=True,
        num_workers=2,
        pin_memory=True
    )
    client_test_loaders[cid] = DataLoader(
        Subset(trainset, test_idx),
        batch_size=TEST_BATCH,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )

print("Client splits complete (train/test counts):")
for cid in range(NUM_CLIENTS):
    print(f" Client {cid}: train={split_info[cid][0]}, test={split_info[cid][1]}")

# ----------------------------
# Training / Evaluation
# ----------------------------
def train_one_epoch(model, loader, optimizer):
    model.train()
    total_loss, total_correct, total_samples = 0, 0, 0
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward()
        optimizer.step()

        bs = y.size(0)
        total_loss += loss.item() * bs
        total_correct += (out.argmax(1) == y).sum().item()
        total_samples += bs
    if total_samples == 0:
        return 0.0, 0.0
    return total_loss / total_samples, 100 * total_correct / total_samples

def evaluate(model, loader):
    model.eval()
    total_correct, total_samples = 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            out = model(x)
            total_correct += (out.argmax(1) == y).sum().item()
            total_samples += y.size(0)
    if total_samples == 0:
        return 0.0
    return 100 * total_correct / total_samples

# ----------------------------
# Fractional epoch helper
# ----------------------------
def sample_fractional_data(cid, frac, rng):
    pool = client_train_idx[cid]
    n = len(pool)
    take = max(1, int(np.ceil(n * frac)))
    chosen = rng.choice(pool, size=take, replace=False).tolist()
    return chosen

# ----------------------------
# Initialize global model
# ----------------------------
global_model = get_model()
global_state = {k: v.cpu() for k, v in global_model.state_dict().items()}

records = []

# ----------------------------
# Federated rounds
# ----------------------------
for rnd in range(1, ROUNDS+1):
    print(f"\n======== ROUND {rnd}/{ROUNDS} ========")
    client_states = {}
    latest_record = {}
    fractional_mode = (LOCAL_EPOCHS > 0 and LOCAL_EPOCHS < 1)

    for cid in range(NUM_CLIENTS):
        local_model = get_model().to(device)
        local_model.load_state_dict({k: global_state[k].clone().to(device) for k in global_state})
        optimizer = optim.Adam(local_model.parameters(), lr=LR)
        n_train, n_test = split_info[cid]

        # Fractional epoch mode
        if fractional_mode:
            rng = np.random.RandomState(SEED + rnd*1000 + cid)
            selected = sample_fractional_data(cid, LOCAL_EPOCHS, rng)
            loader = DataLoader(
                Subset(trainset, selected),
                batch_size=TRAIN_BATCH,
                shuffle=True,
                drop_last=True
            )
            train_loss, train_acc = train_one_epoch(local_model, loader, optimizer)
            rec = {
                "round": rnd, "client": cid, "num_train": n_train, "num_test": n_test,
                "epoch": 1, "fraction": LOCAL_EPOCHS,
                "train_loss": train_loss, "train_acc": train_acc,
                "local_test_acc_before_agg": None,
                "global_test_acc_on_client": None,
                "timestamp": datetime.utcnow().isoformat()
            }
            records.append(rec)
            latest_record[cid] = len(records) - 1
            print(f"[Client {cid}] fractional train size={len(selected)} loss={train_loss:.4f} acc={train_acc:.2f}")

        # Integer epoch mode
        else:
            for ep in range(1, int(LOCAL_EPOCHS)+1):
                train_loss, train_acc = train_one_epoch(local_model, client_train_loaders[cid], optimizer)
                rec = {
                    "round": rnd, "client": cid, "num_train": n_train, "num_test": n_test,
                    "epoch": ep, "fraction": 0,
                    "train_loss": train_loss, "train_acc": train_acc,
                    "local_test_acc_before_agg": None,
                    "global_test_acc_on_client": None,
                    "timestamp": datetime.utcnow().isoformat()
                }
                records.append(rec)
                latest_record[cid] = len(records) - 1
                print(f"[Client {cid}] epoch={ep} loss={train_loss:.4f} acc={train_acc:.2f}")

        # Local test before aggregation
        local_acc = evaluate(local_model, client_test_loaders[cid])
        print(f"[Client {cid}] Local test BEFORE aggregation = {local_acc:.2f}%")
        records[latest_record[cid]]["local_test_acc_before_agg"] = local_acc

        # Save local weights for FedAvg
        client_states[cid] = {k: v.cpu() for k, v in local_model.state_dict().items()}

    # FedAvg aggregation
    new_global = {k: torch.zeros_like(global_state[k], dtype=torch.float32) for k in global_state}
    for cid in client_states:
        for k in new_global:
            new_global[k] += client_states[cid][k].float()
    for k in new_global:
        new_global[k] /= NUM_CLIENTS
        new_global[k] = new_global[k].to(global_state[k].dtype)
    global_state = {k: new_global[k].clone() for k in new_global}
    global_model.load_state_dict({k: v.to(device) for k, v in global_state.items()})

    # Evaluate global model per client
    for cid in range(NUM_CLIENTS):
        gacc = evaluate(global_model, client_test_loaders[cid])
        records[latest_record[cid]]["global_test_acc_on_client"] = gacc
        print(f"[Global model] Accuracy on client {cid} test set = {gacc:.2f}%")

    # Autosave after each round
    df = pd.DataFrame(records)
    df.to_csv(AUTOSAVE_PATH, index=False)
    print(f"Autosaved to {AUTOSAVE_PATH}")

print("\nTraining complete. Final CSV saved.")
# Out:
# Client splits complete (train/test counts):
#  Client 0: train=1501, test=79
#  Client 1: train=3751, test=197
#  Client 2: train=4592, test=241
#  Client 3: train=4252, test=223
#  Client 4: train=6998, test=368
#  Client 5: train=6145, test=323
#  Client 6: train=1360, test=71
#  Client 7: train=7877, test=414
#  Client 8: train=4672, test=245
#  Client 9: train=6357, test=334
#
# ======== ROUND 1/100 ========
# [Client 0] fractional train size=16 loss=2.6903 acc=6.25
# /tmp/ipython-input-1366195170.py:167: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# [Client 0] Local test BEFORE aggregation = 54.43%
# [Client 1] fractional train size=38 loss=1.8080 acc=34.38
# [Client 1] Local test BEFORE aggregation = 11.17%
# [Client 2] fractional train size=46 loss=2.0340 acc=18.75
# [Client 2] Local test BEFORE aggregation = 25.31%
# [Client 3] fractional train size=43 loss=2.0457 acc=21.88
# [Client 3] Local test BEFORE aggregation = 55.61%
# [Client 4] fractional train size=70 loss=2.0513 acc=26.56
# [Client 4] Local test BEFORE aggregation = 45.11%
# [Client 5] fractional train size=62 loss=2.4036 acc=18.75
# [Client 5] Local test BEFORE aggregation = 16.10%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 18.31%
# [Client 7] fractional train size=79 loss=2.1740 acc=28.12
# [Client 7] Local test BEFORE aggregation = 24.64%
# [Client 8] fractional train size=47 loss=2.0076 acc=21.88
# [Client 8] Local test BEFORE aggregation = 88.57%
# [Client 9] fractional train size=64 loss=2.0252 acc=35.94
# [Client 9] Local test BEFORE aggregation = 43.41%
# [Global model] Accuracy on client 0 test set = 2.53%
# [Global model] Accuracy on client 1 test set = 19.29%
# [Global model] Accuracy on client 2 test set = 4.15%
# [Global model] Accuracy on client 3 test set = 2.69%
# [Global model] Accuracy on client 4 test set = 29.08%
# [Global model] Accuracy on client 5 test set = 9.91%
# [Global model] Accuracy on client 6 test set = 1.41%
# [Global model] Accuracy on client 7 test set = 25.60%
# [Global model] Accuracy on client 8 test set = 0.00%
# [Global model] Accuracy on client 9 test set = 12.28%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 2/100 ========
# [Client 0] fractional train size=16 loss=2.6428 acc=0.00
# [Client 0] Local test BEFORE aggregation = 51.90%
# [Client 1] fractional train size=38 loss=1.8446 acc=43.75
# [Client 1] Local test BEFORE aggregation = 37.06%
# [Client 2] fractional train size=46 loss=2.2064 acc=28.12
# [Client 2] Local test BEFORE aggregation = 32.78%
# [Client 3] fractional train size=43 loss=1.8256 acc=40.62
# [Client 3] Local test BEFORE aggregation = 56.95%
# [Client 4] fractional train size=70 loss=1.9411 acc=43.75
# [Client 4] Local test BEFORE aggregation = 38.86%
# [Client 5] fractional train size=62 loss=2.2888 acc=18.75
# [Client 5] Local test BEFORE aggregation = 27.86%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 1.41%
# [Client 7] fractional train size=79 loss=2.4245 acc=20.31
# [Client 7] Local test BEFORE aggregation = 29.23%
# [Client 8] fractional train size=47 loss=2.1223 acc=21.88
# [Client 8] Local test BEFORE aggregation = 88.16%
# [Client 9] fractional train size=64 loss=1.8993 acc=37.50
# [Client 9] Local test BEFORE aggregation = 47.31%
# [Global model] Accuracy on client 0 test set = 21.52%
# [Global model] Accuracy on client 1 test set = 23.86%
# [Global model] Accuracy on client 2 test set = 21.16%
# [Global model] Accuracy on client 3 test set = 8.07%
# [Global model] Accuracy on client 4 test set = 16.85%
# [Global model] Accuracy on client 5 test set = 11.46%
# [Global model] Accuracy on client 6 test set = 15.49%
# [Global model] Accuracy on client 7 test set = 15.22%
# [Global model] Accuracy on client 8 test set = 0.82%
# [Global model] Accuracy on client 9 test set = 9.28%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 3/100 ========
# [Client 0] fractional train size=16 loss=2.3277 acc=6.25
# [Client 0] Local test BEFORE aggregation = 32.91%
# [Client 1] fractional train size=38 loss=1.8402 acc=40.62
# [Client 1] Local test BEFORE aggregation = 33.50%
# [Client 2] fractional train size=46 loss=2.1156 acc=28.12
# [Client 2] Local test BEFORE aggregation = 26.56%
# [Client 3] fractional train size=43 loss=2.0592 acc=50.00
# [Client 3] Local test BEFORE aggregation = 56.95%
# [Client 4] fractional train size=70 loss=1.7743 acc=40.62
# [Client 4] Local test BEFORE aggregation = 52.72%
# [Client 5] fractional train size=62 loss=1.9761 acc=33.33
# [Client 5] Local test BEFORE aggregation = 28.17%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 26.76%
# [Client 7] fractional train size=79 loss=2.0446 acc=35.94
# [Client 7] Local test BEFORE aggregation = 37.44%
# [Client 8] fractional train size=47 loss=2.4070 acc=9.38
# [Client 8] Local test BEFORE aggregation = 53.47%
# [Client 9] fractional train size=64 loss=1.9367 acc=37.50
# [Client 9] Local test BEFORE aggregation = 46.71%
# [Global model] Accuracy on client 0 test set = 8.86%
# [Global model] Accuracy on client 1 test set = 24.37%
# [Global model] Accuracy on client 2 test set = 17.01%
# [Global model] Accuracy on client 3 test set = 1.79%
# [Global model] Accuracy on client 4 test set = 15.76%
# [Global model] Accuracy on client 5 test set = 21.05%
# [Global model] Accuracy on client 6 test set = 22.54%
# [Global model] Accuracy on client 7 test set = 20.77%
# [Global model] Accuracy on client 8 test set = 2.04%
# [Global model] Accuracy on client 9 test set = 7.78%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 4/100 ========
# [Client 0] fractional train size=16 loss=2.8405 acc=6.25
# [Client 0] Local test BEFORE aggregation = 39.24%
# [Client 1] fractional train size=38 loss=1.9333 acc=31.25
# [Client 1] Local test BEFORE aggregation = 35.53%
# [Client 2] fractional train size=46 loss=2.0062 acc=31.25
# [Client 2] Local test BEFORE aggregation = 29.05%
# [Client 3] fractional train size=43 loss=2.0289 acc=34.38
# [Client 3] Local test BEFORE aggregation = 60.99%
# [Client 4] fractional train size=70 loss=1.8898 acc=40.62
# [Client 4] Local test BEFORE aggregation = 51.36%
# [Client 5] fractional train size=62 loss=1.6033 acc=45.83
# [Client 5] Local test BEFORE aggregation = 38.08%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 21.13%
# [Client 7] fractional train size=79 loss=1.8889 acc=42.19
# [Client 7] Local test BEFORE aggregation = 39.86%
# [Client 8] fractional train size=47 loss=2.5662 acc=12.50
# [Client 8] Local test BEFORE aggregation = 48.16%
# [Client 9] fractional train size=64 loss=1.9641 acc=29.69
# [Client 9] Local test BEFORE aggregation = 41.02%
# [Global model] Accuracy on client 0 test set = 6.33%
# [Global model] Accuracy on client 1 test set = 21.32%
# [Global model] Accuracy on client 2 test set = 11.62%
# [Global model] Accuracy on client 3 test set = 1.35%
# [Global model] Accuracy on client 4 test set = 10.60%
# [Global model] Accuracy on client 5 test set = 26.32%
# [Global model] Accuracy on client 6 test set = 9.86%
# [Global model] Accuracy on client 7 test set = 28.02%
# [Global model] Accuracy on client 8 test set = 0.41%
# [Global model] Accuracy on client 9 test set = 11.38%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 5/100 ========
# [Client 0] fractional train size=16 loss=2.1787 acc=18.75
# [Client 0] Local test BEFORE aggregation = 27.85%
# [Client 1] fractional train size=38 loss=2.0710 acc=34.38
# [Client 1] Local test BEFORE aggregation = 45.69%
# [Client 2] fractional train size=46 loss=2.4003 acc=12.50
# [Client 2] Local test BEFORE aggregation = 33.61%
# [Client 3] fractional train size=43 loss=2.1126 acc=31.25
# [Client 3] Local test BEFORE aggregation = 42.60%
# [Client 4] fractional train size=70 loss=2.0334 acc=35.94
# [Client 4] Local test BEFORE aggregation = 42.39%
# [Client 5] fractional train size=62 loss=1.7139 acc=45.83
# [Client 5] Local test BEFORE aggregation = 43.34%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 11.27%
# [Client 7] fractional train size=79 loss=1.9241 acc=40.62
# [Client 7] Local test BEFORE aggregation = 26.81%
# [Client 8] fractional train size=47 loss=2.6258 acc=18.75
# [Client 8] Local test BEFORE aggregation = 30.61%
# [Client 9] fractional train size=64 loss=1.9197 acc=37.50
# [Client 9] Local test BEFORE aggregation = 46.41%
# [Global model] Accuracy on client 0 test set = 10.13%
# [Global model] Accuracy on client 1 test set = 31.47%
# [Global model] Accuracy on client 2 test set = 17.43%
# [Global model] Accuracy on client 3 test set = 2.24%
# [Global model] Accuracy on client 4 test set = 14.13%
# [Global model] Accuracy on client 5 test set = 28.79%
# [Global model] Accuracy on client 6 test set = 32.39%
# [Global model] Accuracy on client 7 test set = 20.29%
# [Global model] Accuracy on client 8 test set = 2.04%
# [Global model] Accuracy on client 9 test set = 8.68%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 6/100 ========
# [Client 0] fractional train size=16 loss=2.7541 acc=6.25
# [Client 0] Local test BEFORE aggregation = 46.84%
# [Client 1] fractional train size=38 loss=1.7468 acc=31.25
# [Client 1] Local test BEFORE aggregation = 48.22%
# [Client 2] fractional train size=46 loss=2.2146 acc=15.62
# [Client 2] Local test BEFORE aggregation = 27.80%
# [Client 3] fractional train size=43 loss=1.9585 acc=28.12
# [Client 3] Local test BEFORE aggregation = 50.67%
# [Client 4] fractional train size=70 loss=1.4977 acc=59.38
# [Client 4] Local test BEFORE aggregation = 50.54%
# [Client 5] fractional train size=62 loss=2.0304 acc=41.67
# [Client 5] Local test BEFORE aggregation = 38.39%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 26.76%
# [Client 7] fractional train size=79 loss=2.1822 acc=35.94
# [Client 7] Local test BEFORE aggregation = 33.09%
# [Client 8] fractional train size=47 loss=2.8356 acc=6.25
# [Client 8] Local test BEFORE aggregation = 8.98%
# [Client 9] fractional train size=64 loss=1.8421 acc=37.50
# [Client 9] Local test BEFORE aggregation = 52.40%
# [Global model] Accuracy on client 0 test set = 8.86%
# [Global model] Accuracy on client 1 test set = 31.47%
# [Global model] Accuracy on client 2 test set = 16.18%
# [Global model] Accuracy on client 3 test set = 6.28%
# [Global model] Accuracy on client 4 test set = 15.22%
# [Global model] Accuracy on client 5 test set = 28.17%
# [Global model] Accuracy on client 6 test set = 21.13%
# [Global model] Accuracy on client 7 test set = 23.19%
# [Global model] Accuracy on client 8 test set = 2.45%
# [Global model] Accuracy on client 9 test set = 14.67%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 7/100 ========
# [Client 0] fractional train size=16 loss=2.5491 acc=6.25
# [Client 0] Local test BEFORE aggregation = 17.72%
# [Client 1] fractional train size=38 loss=1.5513 acc=37.50
# [Client 1] Local test BEFORE aggregation = 37.56%
# [Client 2] fractional train size=46 loss=2.4803 acc=12.50
# [Client 2] Local test BEFORE aggregation = 31.12%
# [Client 3] fractional train size=43 loss=2.2930 acc=15.62
# [Client 3] Local test BEFORE aggregation = 64.57%
# [Client 4] fractional train size=70 loss=1.7776 acc=42.19
# [Client 4] Local test BEFORE aggregation = 61.68%
# [Client 5] fractional train size=62 loss=2.0712 acc=29.17
# [Client 5] Local test BEFORE aggregation = 43.34%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 21.13%
# [Client 7] fractional train size=79 loss=1.9992 acc=29.69
# [Client 7] Local test BEFORE aggregation = 32.85%
# [Client 8] fractional train size=47 loss=3.1069 acc=0.00
# [Client 8] Local test BEFORE aggregation = 43.27%
# [Client 9] fractional train size=64 loss=1.7959 acc=42.19
# [Client 9] Local test BEFORE aggregation = 48.20%
# [Global model] Accuracy on client 0 test set = 7.59%
# [Global model] Accuracy on client 1 test set = 26.40%
# [Global model] Accuracy on client 2 test set = 13.28%
# [Global model] Accuracy on client 3 test set = 8.07%
# [Global model] Accuracy on client 4 test set = 10.87%
# [Global model] Accuracy on client 5 test set = 38.70%
# [Global model] Accuracy on client 6 test set = 14.08%
# [Global model] Accuracy on client 7 test set = 28.50%
# [Global model] Accuracy on client 8 test set = 2.86%
# [Global model] Accuracy on client 9 test set = 19.16%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 8/100 ========
# [Client 0] fractional train size=16 loss=2.2650 acc=6.25
# [Client 0] Local test BEFORE aggregation = 32.91%
# [Client 1] fractional train size=38 loss=1.8738 acc=37.50
# [Client 1] Local test BEFORE aggregation = 37.06%
# [Client 2] fractional train size=46 loss=2.3846 acc=25.00
# [Client 2] Local test BEFORE aggregation = 35.27%
# [Client 3] fractional train size=43 loss=2.3532 acc=21.88
# [Client 3] Local test BEFORE aggregation = 67.26%
# [Client 4] fractional train size=70 loss=1.8244 acc=46.88
# [Client 4] Local test BEFORE aggregation = 47.55%
# [Client 5] fractional train size=62 loss=1.9847 acc=35.42
# [Client 5] Local test BEFORE aggregation = 37.15%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 16.90%
# [Client 7] fractional train size=79 loss=2.0865 acc=35.94
# [Client 7] Local test BEFORE aggregation = 40.58%
# [Client 8] fractional train size=47 loss=2.8872 acc=12.50
# [Client 8] Local test BEFORE aggregation = 28.98%
# [Client 9] fractional train size=64 loss=2.0149 acc=45.31
# [Client 9] Local test BEFORE aggregation = 49.70%
# [Global model] Accuracy on client 0 test set = 15.19%
# [Global model] Accuracy on client 1 test set = 25.89%
# [Global model] Accuracy on client 2 test set = 10.37%
# [Global model] Accuracy on client 3 test set = 21.97%
# [Global model] Accuracy on client 4 test set = 9.24%
# [Global model] Accuracy on client 5 test set = 38.39%
# [Global model] Accuracy on client 6 test set = 25.35%
# [Global model] Accuracy on client 7 test set = 29.47%
# [Global model] Accuracy on client 8 test set = 5.31%
# [Global model] Accuracy on client 9 test set = 18.56%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 9/100 ========
# [Client 0] fractional train size=16 loss=2.4291 acc=6.25
# [Client 0] Local test BEFORE aggregation = 45.57%
# [Client 1] fractional train size=38 loss=1.9062 acc=28.12
# [Client 1] Local test BEFORE aggregation = 35.53%
# [Client 2] fractional train size=46 loss=2.2435 acc=21.88
# [Client 2] Local test BEFORE aggregation = 35.68%
# [Client 3] fractional train size=43 loss=2.1705 acc=25.00
# [Client 3] Local test BEFORE aggregation = 47.53%
# [Client 4] fractional train size=70 loss=1.8712 acc=46.88
# [Client 4] Local test BEFORE aggregation = 59.51%
# [Client 5] fractional train size=62 loss=2.2226 acc=20.83
# [Client 5] Local test BEFORE aggregation = 42.72%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 16.90%
# [Client 7] fractional train size=79 loss=1.8756 acc=39.06
# [Client 7] Local test BEFORE aggregation = 39.37%
# [Client 8] fractional train size=47 loss=2.9221 acc=12.50
# [Client 8] Local test BEFORE aggregation = 54.29%
# [Client 9] fractional train size=64 loss=1.9909 acc=37.50
# [Client 9] Local test BEFORE aggregation = 44.61%
# [Global model] Accuracy on client 0 test set = 17.72%
# [Global model] Accuracy on client 1 test set = 29.95%
# [Global model] Accuracy on client 2 test set = 6.22%
# [Global model] Accuracy on client 3 test set = 0.00%
# [Global model] Accuracy on client 4 test set = 20.11%
# [Global model] Accuracy on client 5 test set = 36.84%
# [Global model] Accuracy on client 6 test set = 1.41%
# [Global model] Accuracy on client 7 test set = 37.44%
# [Global model] Accuracy on client 8 test set = 1.63%
# [Global model] Accuracy on client 9 test set = 17.96%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 10/100 ========
# [Client 0] fractional train size=16 loss=2.2555 acc=18.75
# [Client 0] Local test BEFORE aggregation = 49.37%
# [Client 1] fractional train size=38 loss=1.8765 acc=40.62
# [Client 1] Local test BEFORE aggregation = 21.83%
# [Client 2] fractional train size=46 loss=2.5080 acc=15.62
# [Client 2] Local test BEFORE aggregation = 25.73%
# [Client 3] fractional train size=43 loss=1.9817 acc=28.12
# [Client 3] Local test BEFORE aggregation = 51.57%
# [Client 4] fractional train size=70 loss=1.8214 acc=43.75
# [Client 4] Local test BEFORE aggregation = 45.38%
# [Client 5] fractional train size=62 loss=1.7899 acc=33.33
# [Client 5] Local test BEFORE aggregation = 45.51%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 7.04%
# [Client 7] fractional train size=79 loss=1.9860 acc=39.06
# [Client 7] Local test BEFORE aggregation = 34.30%
# [Client 8] fractional train size=47 loss=3.2487 acc=3.12
# [Client 8] Local test BEFORE aggregation = 64.90%
# [Client 9] fractional train size=64 loss=1.9401 acc=40.62
# [Client 9] Local test BEFORE aggregation = 41.92%
# [Global model] Accuracy on client 0 test set = 15.19%
# [Global model] Accuracy on client 1 test set = 36.55%
# [Global model] Accuracy on client 2 test set = 7.05%
# [Global model] Accuracy on client 3 test set = 2.24%
# [Global model] Accuracy on client 4 test set = 11.68%
# [Global model] Accuracy on client 5 test set = 44.58%
# [Global model] Accuracy on client 6 test set = 12.68%
# [Global model] Accuracy on client 7 test set = 29.71%
# [Global model] Accuracy on client 8 test set = 1.63%
# [Global model] Accuracy on client 9 test set = 25.45%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 11/100 ========
# [Client 0] fractional train size=16 loss=2.2845 acc=25.00
# [Client 0] Local test BEFORE aggregation = 39.24%
# [Client 1] fractional train size=38 loss=2.0831 acc=28.12
# [Client 1] Local test BEFORE aggregation = 36.04%
# [Client 2] fractional train size=46 loss=2.4422 acc=18.75
# [Client 2] Local test BEFORE aggregation = 31.95%
# [Client 3] fractional train size=43 loss=2.1256 acc=34.38
# [Client 3] Local test BEFORE aggregation = 58.30%
# [Client 4] fractional train size=70 loss=1.6523 acc=43.75
# [Client 4] Local test BEFORE aggregation = 41.85%
# [Client 5] fractional train size=62 loss=1.9833 acc=29.17
# [Client 5] Local test BEFORE aggregation = 32.20%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 11.27%
# [Client 7] fractional train size=79 loss=2.1495 acc=35.94
# [Client 7] Local test BEFORE aggregation = 29.71%
# [Client 8] fractional train size=47 loss=3.2506 acc=9.38
# [Client 8] Local test BEFORE aggregation = 28.57%
# [Client 9] fractional train size=64 loss=1.7942 acc=40.62
# [Client 9] Local test BEFORE aggregation = 40.72%
# [Global model] Accuracy on client 0 test set = 15.19%
# [Global model] Accuracy on client 1 test set = 36.55%
# [Global model] Accuracy on client 2 test set = 10.79%
# [Global model] Accuracy on client 3 test set = 2.69%
# [Global model] Accuracy on client 4 test set = 19.02%
# [Global model] Accuracy on client 5 test set = 36.53%
# [Global model] Accuracy on client 6 test set = 16.90%
# [Global model] Accuracy on client 7 test set = 36.47%
# [Global model] Accuracy on client 8 test set = 2.45%
# [Global model] Accuracy on client 9 test set = 20.66%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 12/100 ========
# [Client 0] fractional train size=16 loss=1.9556 acc=43.75
# [Client 0] Local test BEFORE aggregation = 53.16%
# [Client 1] fractional train size=38 loss=1.9124 acc=37.50
# [Client 1] Local test BEFORE aggregation = 36.55%
# [Client 2] fractional train size=46 loss=2.8204 acc=6.25
# [Client 2] Local test BEFORE aggregation = 33.61%
# [Client 3] fractional train size=43 loss=2.1615 acc=28.12
# [Client 3] Local test BEFORE aggregation = 52.02%
# [Client 4] fractional train size=70 loss=1.5026 acc=51.56
# [Client 4] Local test BEFORE aggregation = 37.50%
# [Client 5] fractional train size=62 loss=2.0692 acc=33.33
# [Client 5] Local test BEFORE aggregation = 38.08%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 14.08%
# [Client 7] fractional train size=79 loss=1.9220 acc=35.94
# [Client 7] Local test BEFORE aggregation = 28.99%
# [Client 8] fractional train size=47 loss=3.3314 acc=6.25
# [Client 8] Local test BEFORE aggregation = 51.43%
# [Client 9] fractional train size=64 loss=1.5527 acc=57.81
# [Client 9] Local test BEFORE aggregation = 40.42%
# [Global model] Accuracy on client 0 test set = 12.66%
# [Global model] Accuracy on client 1 test set = 35.53%
# [Global model] Accuracy on client 2 test set = 6.22%
# [Global model] Accuracy on client 3 test set = 14.80%
# [Global model] Accuracy on client 4 test set = 7.07%
# [Global model] Accuracy on client 5 test set = 45.51%
# [Global model] Accuracy on client 6 test set = 18.31%
# [Global model] Accuracy on client 7 test set = 35.75%
# [Global model] Accuracy on client 8 test set = 4.08%
# [Global model] Accuracy on client 9 test set = 25.75%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 13/100 ========
# [Client 0] fractional train size=16 loss=2.1998 acc=18.75
# [Client 0] Local test BEFORE aggregation = 48.10%
# [Client 1] fractional train size=38 loss=1.8435 acc=28.12
# [Client 1] Local test BEFORE aggregation = 32.99%
# [Client 2] fractional train size=46 loss=2.2196 acc=31.25
# [Client 2] Local test BEFORE aggregation = 22.41%
# [Client 3] fractional train size=43 loss=2.3477 acc=25.00
# [Client 3] Local test BEFORE aggregation = 55.16%
# [Client 4] fractional train size=70 loss=1.7503 acc=43.75
# [Client 4] Local test BEFORE aggregation = 50.54%
# [Client 5] fractional train size=62 loss=1.7897 acc=39.58
# [Client 5] Local test BEFORE aggregation = 34.67%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 21.13%
# [Client 7] fractional train size=79 loss=1.8329 acc=31.25
# [Client 7] Local test BEFORE aggregation = 44.44%
# [Client 8] fractional train size=47 loss=3.2269 acc=15.62
# [Client 8] Local test BEFORE aggregation = 22.45%
# [Client 9] fractional train size=64 loss=1.8575 acc=42.19
# [Client 9] Local test BEFORE aggregation = 45.51%
# [Global model] Accuracy on client 0 test set = 15.19%
# [Global model] Accuracy on client 1 test set = 26.90%
# [Global model] Accuracy on client 2 test set = 8.71%
# [Global model] Accuracy on client 3 test set = 4.04%
# [Global model] Accuracy on client 4 test set = 19.29%
# [Global model] Accuracy on client 5 test set = 38.70%
# [Global model] Accuracy on client 6 test set = 12.68%
# [Global model] Accuracy on client 7 test set = 42.27%
# [Global model] Accuracy on client 8 test set = 1.63%
# [Global model] Accuracy on client 9 test set = 20.36%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 14/100 ========
# [Client 0] fractional train size=16 loss=1.8907 acc=43.75
# [Client 0] Local test BEFORE aggregation = 45.57%
# [Client 1] fractional train size=38 loss=1.9559 acc=31.25
# [Client 1] Local test BEFORE aggregation = 41.62%
# [Client 2] fractional train size=46 loss=2.5988 acc=15.62
# [Client 2] Local test BEFORE aggregation = 31.12%
# [Client 3] fractional train size=43 loss=2.1242 acc=28.12
# [Client 3] Local test BEFORE aggregation = 63.23%
# [Client 4] fractional train size=70 loss=1.8384 acc=37.50
# [Client 4] Local test BEFORE aggregation = 46.20%
# [Client 5] fractional train size=62 loss=1.8363 acc=37.50
# [Client 5] Local test BEFORE aggregation = 37.77%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 4.23%
# [Client 7] fractional train size=79 loss=1.9424 acc=28.12
# [Client 7] Local test BEFORE aggregation = 27.78%
# [Client 8] fractional train size=47 loss=3.2698 acc=15.62
# [Client 8] Local test BEFORE aggregation = 60.41%
# [Client 9] fractional train size=64 loss=1.8471 acc=42.19
# [Client 9] Local test BEFORE aggregation = 53.59%
# [Global model] Accuracy on client 0 test set = 20.25%
# [Global model] Accuracy on client 1 test set = 33.50%
# [Global model] Accuracy on client 2 test set = 7.47%
# [Global model] Accuracy on client 3 test set = 11.66%
# [Global model] Accuracy on client 4 test set = 18.21%
# [Global model] Accuracy on client 5 test set = 36.84%
# [Global model] Accuracy on client 6 test set = 25.35%
# [Global model] Accuracy on client 7 test set = 36.23%
# [Global model] Accuracy on client 8 test set = 4.08%
# [Global model] Accuracy on client 9 test set = 23.95%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 15/100 ========
# [Client 0] fractional train size=16 loss=2.1551 acc=18.75
# [Client 0] Local test BEFORE aggregation = 29.11%
# [Client 1] fractional train size=38 loss=2.0831 acc=37.50
# [Client 1] Local test BEFORE aggregation = 31.98%
# [Client 2] fractional train size=46 loss=2.4506 acc=28.12
# [Client 2] Local test BEFORE aggregation = 23.65%
# [Client 3] fractional train size=43 loss=2.3119 acc=31.25
# [Client 3] Local test BEFORE aggregation = 51.12%
# [Client 4] fractional train size=70 loss=1.8330 acc=40.62
# [Client 4] Local test BEFORE aggregation = 44.57%
# [Client 5] fractional train size=62 loss=1.9907 acc=35.42
# [Client 5] Local test BEFORE aggregation = 44.27%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 19.72%
# [Client 7] fractional train size=79 loss=2.1432 acc=34.38
# [Client 7] Local test BEFORE aggregation = 25.85%
# [Client 8] fractional train size=47 loss=2.9241 acc=21.88
# [Client 8] Local test BEFORE aggregation = 66.12%
# [Client 9] fractional train size=64 loss=1.6902 acc=45.31
# [Client 9] Local test BEFORE aggregation = 47.01%
# [Global model] Accuracy on client 0 test set = 13.92%
# [Global model] Accuracy on client 1 test set = 31.47%
# [Global model] Accuracy on client 2 test set = 4.56%
# [Global model] Accuracy on client 3 test set = 15.25%
# [Global model] Accuracy on client 4 test set = 23.64%
# [Global model] Accuracy on client 5 test set = 34.06%
# [Global model] Accuracy on client 6 test set = 11.27%
# [Global model] Accuracy on client 7 test set = 39.37%
# [Global model] Accuracy on client 8 test set = 2.45%
# [Global model] Accuracy on client 9 test set = 22.46%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 16/100 ========
# [Client 0] fractional train size=16 loss=2.4699 acc=6.25
# [Client 0] Local test BEFORE aggregation = 50.63%
# [Client 1] fractional train size=38 loss=2.1698 acc=21.88
# [Client 1] Local test BEFORE aggregation = 40.61%
# [Client 2] fractional train size=46 loss=2.4683 acc=21.88
# [Client 2] Local test BEFORE aggregation = 28.22%
# [Client 3] fractional train size=43 loss=2.4581 acc=21.88
# [Client 3] Local test BEFORE aggregation = 61.43%
# [Client 4] fractional train size=70 loss=1.7104 acc=46.88
# [Client 4] Local test BEFORE aggregation = 38.32%
# [Client 5] fractional train size=62 loss=1.8973 acc=41.67
# [Client 5] Local test BEFORE aggregation = 47.06%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 12.68%
# [Client 7] fractional train size=79 loss=2.0658 acc=29.69
# [Client 7] Local test BEFORE aggregation = 27.78%
# [Client 8] fractional train size=47 loss=3.4159 acc=12.50
# [Client 8] Local test BEFORE aggregation = 4.08%
# [Client 9] fractional train size=64 loss=1.9322 acc=34.38
# [Client 9] Local test BEFORE aggregation = 36.23%
# [Global model] Accuracy on client 0 test set = 17.72%
# [Global model] Accuracy on client 1 test set = 36.04%
# [Global model] Accuracy on client 2 test set = 9.96%
# [Global model] Accuracy on client 3 test set = 9.42%
# [Global model] Accuracy on client 4 test set = 7.88%
# [Global model] Accuracy on client 5 test set = 45.82%
# [Global model] Accuracy on client 6 test set = 11.27%
# [Global model] Accuracy on client 7 test set = 34.30%
# [Global model] Accuracy on client 8 test set = 2.86%
# [Global model] Accuracy on client 9 test set = 25.15%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 17/100 ========
# [Client 0] fractional train size=16 loss=2.2782 acc=12.50
# [Client 0] Local test BEFORE aggregation = 30.38%
# [Client 1] fractional train size=38 loss=1.9859 acc=34.38
# [Client 1] Local test BEFORE aggregation = 32.99%
# [Client 2] fractional train size=46 loss=2.5566 acc=12.50
# [Client 2] Local test BEFORE aggregation = 26.97%
# [Client 3] fractional train size=43 loss=1.9130 acc=37.50
# [Client 3] Local test BEFORE aggregation = 62.33%
# [Client 4] fractional train size=70 loss=1.6114 acc=46.88
# [Client 4] Local test BEFORE aggregation = 39.95%
# [Client 5] fractional train size=62 loss=1.7604 acc=39.58
# [Client 5] Local test BEFORE aggregation = 20.43%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 14.08%
# [Client 7] fractional train size=79 loss=1.9762 acc=35.94
# [Client 7] Local test BEFORE aggregation = 31.88%
# [Client 8] fractional train size=47 loss=3.4979 acc=9.38
# [Client 8] Local test BEFORE aggregation = 0.00%
# [Client 9] fractional train size=64 loss=1.7848 acc=42.19
# [Client 9] Local test BEFORE aggregation = 49.70%
# [Global model] Accuracy on client 0 test set = 17.72%
# [Global model] Accuracy on client 1 test set = 28.93%
# [Global model] Accuracy on client 2 test set = 8.30%
# [Global model] Accuracy on client 3 test set = 16.14%
# [Global model] Accuracy on client 4 test set = 30.98%
# [Global model] Accuracy on client 5 test set = 31.58%
# [Global model] Accuracy on client 6 test set = 8.45%
# [Global model] Accuracy on client 7 test set = 43.72%
# [Global model] Accuracy on client 8 test set = 2.04%
# [Global model] Accuracy on client 9 test set = 12.57%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 18/100 ========
# [Client 0] fractional train size=16 loss=2.3018 acc=6.25
# [Client 0] Local test BEFORE aggregation = 43.04%
# [Client 1] fractional train size=38 loss=2.0950 acc=25.00
# [Client 1] Local test BEFORE aggregation = 37.06%
# [Client 2] fractional train size=46 loss=2.2608 acc=12.50
# [Client 2] Local test BEFORE aggregation = 28.63%
# [Client 3] fractional train size=43 loss=2.1241 acc=25.00
# [Client 3] Local test BEFORE aggregation = 57.85%
# [Client 4] fractional train size=70 loss=1.4673 acc=59.38
# [Client 4] Local test BEFORE aggregation = 40.22%
# [Client 5] fractional train size=62 loss=1.6758 acc=39.58
# [Client 5] Local test BEFORE aggregation = 46.75%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 15.49%
# [Client 7] fractional train size=79 loss=1.8417 acc=45.31
# [Client 7] Local test BEFORE aggregation = 40.82%
# [Client 8] fractional train size=47 loss=3.6117 acc=6.25
# [Client 8] Local test BEFORE aggregation = 14.29%
# [Client 9] fractional train size=64 loss=1.4574 acc=48.44
# [Client 9] Local test BEFORE aggregation = 28.14%
# [Global model] Accuracy on client 0 test set = 27.85%
# [Global model] Accuracy on client 1 test set = 24.87%
# [Global model] Accuracy on client 2 test set = 9.96%
# [Global model] Accuracy on client 3 test set = 7.17%
# [Global model] Accuracy on client 4 test set = 4.35%
# [Global model] Accuracy on client 5 test set = 42.11%
# [Global model] Accuracy on client 6 test set = 15.49%
# [Global model] Accuracy on client 7 test set = 35.27%
# [Global model] Accuracy on client 8 test set = 1.22%
# [Global model] Accuracy on client 9 test set = 35.33%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 19/100 ========
# [Client 0] fractional train size=16 loss=2.2796 acc=18.75
# [Client 0] Local test BEFORE aggregation = 36.71%
# [Client 1] fractional train size=38 loss=2.1061 acc=25.00
# [Client 1] Local test BEFORE aggregation = 44.67%
# [Client 2] fractional train size=46 loss=2.4002 acc=18.75
# [Client 2] Local test BEFORE aggregation = 29.05%
# [Client 3] fractional train size=43 loss=1.9774 acc=37.50
# [Client 3] Local test BEFORE aggregation = 59.19%
# [Client 4] fractional train size=70 loss=1.3842 acc=50.00
# [Client 4] Local test BEFORE aggregation = 36.14%
# [Client 5] fractional train size=62 loss=1.8767 acc=35.42
# [Client 5] Local test BEFORE aggregation = 47.99%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 15.49%
# [Client 7] fractional train size=79 loss=1.9503 acc=29.69
# [Client 7] Local test BEFORE aggregation = 38.65%
# [Client 8] fractional train size=47 loss=3.6517 acc=3.12
# [Client 8] Local test BEFORE aggregation = 40.00%
# [Client 9] fractional train size=64 loss=1.7870 acc=39.06
# [Client 9] Local test BEFORE aggregation = 41.62%
# [Global model] Accuracy on client 0 test set = 16.46%
# [Global model] Accuracy on client 1 test set = 29.44%
# [Global model] Accuracy on client 2 test set = 15.35%
# [Global model] Accuracy on client 3 test set = 13.90%
# [Global model] Accuracy on client 4 test set = 23.37%
# [Global model] Accuracy on client 5 test set = 26.93%
# [Global model] Accuracy on client 6 test set = 21.13%
# [Global model] Accuracy on client 7 test set = 23.91%
# [Global model] Accuracy on client 8 test set = 4.49%
# [Global model] Accuracy on client 9 test set = 18.86%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 20/100 ========
# [Client 0] fractional train size=16 loss=2.4467 acc=6.25
# [Client 0] Local test BEFORE aggregation = 49.37%
# [Client 1] fractional train size=38 loss=1.8716 acc=25.00
# [Client 1] Local test BEFORE aggregation = 31.47%
# [Client 2] fractional train size=46 loss=2.1945 acc=21.88
# [Client 2] Local test BEFORE aggregation = 27.80%
# [Client 3] fractional train size=43 loss=2.1989 acc=31.25
# [Client 3] Local test BEFORE aggregation = 51.12%
# [Client 4] fractional train size=70 loss=2.1354 acc=35.94
# [Client 4] Local test BEFORE aggregation = 63.32%
# [Client 5] fractional train size=62 loss=1.8676 acc=33.33
# [Client 5] Local test BEFORE aggregation = 34.67%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 14.08%
# [Client 7] fractional train size=79 loss=1.7926 acc=37.50
# [Client 7] Local test BEFORE aggregation = 34.78%
# [Client 8] fractional train size=47 loss=3.3749 acc=12.50
# [Client 8] Local test BEFORE aggregation = 4.90%
# [Client 9] fractional train size=64 loss=1.4485 acc=48.44
# [Client 9] Local test BEFORE aggregation = 33.23%
# [Global model] Accuracy on client 0 test set = 18.99%
# [Global model] Accuracy on client 1 test set = 26.90%
# [Global model] Accuracy on client 2 test set = 11.62%
# [Global model] Accuracy on client 3 test set = 8.52%
# [Global model] Accuracy on client 4 test set = 10.33%
# [Global model] Accuracy on client 5 test set = 42.41%
# [Global model] Accuracy on client 6 test set = 11.27%
# [Global model] Accuracy on client 7 test set = 37.92%
# [Global model] Accuracy on client 8 test set = 1.63%
# [Global model] Accuracy on client 9 test set = 40.72%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 21/100 ========
# [Client 0] fractional train size=16 loss=2.1230 acc=6.25
# [Client 0] Local test BEFORE aggregation = 22.78%
# [Client 1] fractional train size=38 loss=1.8592 acc=34.38
# [Client 1] Local test BEFORE aggregation = 29.95%
# [Client 2] fractional train size=46 loss=2.6384 acc=9.38
# [Client 2] Local test BEFORE aggregation = 40.25%
# [Client 3] fractional train size=43 loss=1.7682 acc=37.50
# [Client 3] Local test BEFORE aggregation = 62.78%
# [Client 4] fractional train size=70 loss=1.9833 acc=31.25
# [Client 4] Local test BEFORE aggregation = 35.60%
# [Client 5] fractional train size=62 loss=2.1315 acc=33.33
# [Client 5] Local test BEFORE aggregation = 34.37%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 18.31%
# [Client 7] fractional train size=79 loss=1.9640 acc=40.62
# [Client 7] Local test BEFORE aggregation = 34.30%
# [Client 8] fractional train size=47 loss=3.3223 acc=12.50
# [Client 8] Local test BEFORE aggregation = 4.49%
# [Client 9] fractional train size=64 loss=1.3506 acc=60.94
# [Client 9] Local test BEFORE aggregation = 55.39%
# [Global model] Accuracy on client 0 test set = 39.24%
# [Global model] Accuracy on client 1 test set = 26.90%
# [Global model] Accuracy on client 2 test set = 7.88%
# [Global model] Accuracy on client 3 test set = 12.11%
# [Global model] Accuracy on client 4 test set = 29.35%
# [Global model] Accuracy on client 5 test set = 32.20%
# [Global model] Accuracy on client 6 test set = 15.49%
# [Global model] Accuracy on client 7 test set = 42.03%
# [Global model] Accuracy on client 8 test set = 1.22%
# [Global model] Accuracy on client 9 test set = 37.13%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 22/100 ========
# [Client 0] fractional train size=16 loss=2.0112 acc=31.25
# [Client 0] Local test BEFORE aggregation = 31.65%
# [Client 1] fractional train size=38 loss=1.7306 acc=34.38
# [Client 1] Local test BEFORE aggregation = 35.53%
# [Client 2] fractional train size=46 loss=2.1410 acc=25.00
# [Client 2] Local test BEFORE aggregation = 35.27%
# [Client 3] fractional train size=43 loss=2.0713 acc=21.88
# [Client 3] Local test BEFORE aggregation = 61.43%
# [Client 4] fractional train size=70 loss=1.4295 acc=51.56
# [Client 4] Local test BEFORE aggregation = 50.00%
# [Client 5] fractional train size=62 loss=1.7369 acc=47.92
# [Client 5] Local test BEFORE aggregation = 44.27%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 11.27%
# [Client 7] fractional train size=79 loss=1.8811 acc=32.81
# [Client 7] Local test BEFORE aggregation = 30.92%
# [Client 8] fractional train size=47 loss=3.2164 acc=9.38
# [Client 8] Local test BEFORE aggregation = 2.86%
# [Client 9] fractional train size=64 loss=1.6119 acc=59.38
# [Client 9] Local test BEFORE aggregation = 52.69%
# [Global model] Accuracy on client 0 test set = 22.78%
# [Global model] Accuracy on client 1 test set = 38.07%
# [Global model] Accuracy on client 2 test set = 9.54%
# [Global model] Accuracy on client 3 test set = 12.56%
# [Global model] Accuracy on client 4 test set = 10.87%
# [Global model] Accuracy on client 5 test set = 46.13%
# [Global model] Accuracy on client 6 test set = 23.94%
# [Global model] Accuracy on client 7 test set = 28.50%
# [Global model] Accuracy on client 8 test set = 4.49%
# [Global model] Accuracy on client 9 test set = 43.11%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 23/100 ========
# [Client 0] fractional train size=16 loss=2.3846 acc=18.75
# [Client 0] Local test BEFORE aggregation = 25.32%
# [Client 1] fractional train size=38 loss=1.8024 acc=25.00
# [Client 1] Local test BEFORE aggregation = 32.49%
# [Client 2] fractional train size=46 loss=2.1853 acc=18.75
# [Client 2] Local test BEFORE aggregation = 33.20%
# [Client 3] fractional train size=43 loss=2.1906 acc=25.00
# [Client 3] Local test BEFORE aggregation = 64.13%
# [Client 4] fractional train size=70 loss=1.6858 acc=46.88
# [Client 4] Local test BEFORE aggregation = 41.03%
# [Client 5] fractional train size=62 loss=1.6722 acc=45.83
# [Client 5] Local test BEFORE aggregation = 40.56%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 25.35%
# [Client 7] fractional train size=79 loss=1.5999 acc=56.25
# [Client 7] Local test BEFORE aggregation = 40.10%
# [Client 8] fractional train size=47 loss=3.4143 acc=6.25
# [Client 8] Local test BEFORE aggregation = 2.04%
# [Client 9] fractional train size=64 loss=1.4147 acc=56.25
# [Client 9] Local test BEFORE aggregation = 44.01%
# [Global model] Accuracy on client 0 test set = 26.58%
# [Global model] Accuracy on client 1 test set = 36.55%
# [Global model] Accuracy on client 2 test set = 10.37%
# [Global model] Accuracy on client 3 test set = 13.00%
# [Global model] Accuracy on client 4 test set = 13.59%
# [Global model] Accuracy on client 5 test set = 41.80%
# [Global model] Accuracy on client 6 test set = 35.21%
# [Global model] Accuracy on client 7 test set = 31.88%
# [Global model] Accuracy on client 8 test set = 5.31%
# [Global model] Accuracy on client 9 test set = 41.62%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 24/100 ========
# [Client 0] fractional train size=16 loss=2.2756 acc=12.50
# [Client 0] Local test BEFORE aggregation = 59.49%
# [Client 1] fractional train size=38 loss=1.7885 acc=40.62
# [Client 1] Local test BEFORE aggregation = 31.98%
# [Client 2] fractional train size=46 loss=2.4322 acc=9.38
# [Client 2] Local test BEFORE aggregation = 30.71%
# [Client 3] fractional train size=43 loss=1.8326 acc=37.50
# [Client 3] Local test BEFORE aggregation = 49.33%
# [Client 4] fractional train size=70 loss=1.8895 acc=43.75
# [Client 4] Local test BEFORE aggregation = 42.12%
# [Client 5] fractional train size=62 loss=1.8736 acc=43.75
# [Client 5] Local test BEFORE aggregation = 35.29%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 23.94%
# [Client 7] fractional train size=79 loss=1.8595 acc=51.56
# [Client 7] Local test BEFORE aggregation = 40.10%
# [Client 8] fractional train size=47 loss=3.0596 acc=18.75
# [Client 8] Local test BEFORE aggregation = 4.90%
# [Client 9] fractional train size=64 loss=1.7070 acc=46.88
# [Client 9] Local test BEFORE aggregation = 44.01%
# [Global model] Accuracy on client 0 test set = 35.44%
# [Global model] Accuracy on client 1 test set = 24.87%
# [Global model] Accuracy on client 2 test set = 9.13%
# [Global model] Accuracy on client 3 test set = 18.39%
# [Global model] Accuracy on client 4 test set = 15.49%
# [Global model] Accuracy on client 5 test set = 42.72%
# [Global model] Accuracy on client 6 test set = 11.27%
# [Global model] Accuracy on client 7 test set = 46.14%
# [Global model] Accuracy on client 8 test set = 2.04%
# [Global model] Accuracy on client 9 test set = 34.43%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 25/100 ========
# [Client 0] fractional train size=16 loss=1.8072 acc=37.50
# [Client 0] Local test BEFORE aggregation = 46.84%
# [Client 1] fractional train size=38 loss=1.8696 acc=40.62
# [Client 1] Local test BEFORE aggregation = 20.81%
# [Client 2] fractional train size=46 loss=2.0926 acc=28.12
# [Client 2] Local test BEFORE aggregation = 26.97%
# [Client 3] fractional train size=43 loss=2.0576 acc=25.00
# [Client 3] Local test BEFORE aggregation = 52.47%
# [Client 4] fractional train size=70 loss=1.9278 acc=51.56
# [Client 4] Local test BEFORE aggregation = 44.02%
# [Client 5] fractional train size=62 loss=1.9731 acc=39.58
# [Client 5] Local test BEFORE aggregation = 41.18%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 16.90%
# [Client 7] fractional train size=79 loss=1.7784 acc=48.44
# [Client 7] Local test BEFORE aggregation = 41.55%
# [Client 8] fractional train size=47 loss=3.0092 acc=15.62
# [Client 8] Local test BEFORE aggregation = 21.63%
# [Client 9] fractional train size=64 loss=1.8020 acc=59.38
# [Client 9] Local test BEFORE aggregation = 45.51%
# [Global model] Accuracy on client 0 test set = 10.13%
# [Global model] Accuracy on client 1 test set = 31.47%
# [Global model] Accuracy on client 2 test set = 5.81%
# [Global model] Accuracy on client 3 test set = 13.45%
# [Global model] Accuracy on client 4 test set = 5.16%
# [Global model] Accuracy on client 5 test set = 43.96%
# [Global model] Accuracy on client 6 test set = 12.68%
# [Global model] Accuracy on client 7 test set = 42.03%
# [Global model] Accuracy on client 8 test set = 3.27%
# [Global model] Accuracy on client 9 test set = 35.33%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 26/100 ========
# [Client 0] fractional train size=16 loss=2.5401 acc=25.00
# [Client 0] Local test BEFORE aggregation = 49.37%
# [Client 1] fractional train size=38 loss=2.0888 acc=21.88
# [Client 1] Local test BEFORE aggregation = 47.21%
# [Client 2] fractional train size=46 loss=2.2018 acc=28.12
# [Client 2] Local test BEFORE aggregation = 31.54%
# [Client 3] fractional train size=43 loss=1.9015 acc=34.38
# [Client 3] Local test BEFORE aggregation = 64.57%
# [Client 4] fractional train size=70 loss=1.9371 acc=43.75
# [Client 4] Local test BEFORE aggregation = 30.16%
# [Client 5] fractional train size=62 loss=1.7169 acc=43.75
# [Client 5] Local test BEFORE aggregation = 43.34%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 12.68%
# [Client 7] fractional train size=79 loss=1.6911 acc=46.88
# [Client 7] Local test BEFORE aggregation = 39.37%
# [Client 8] fractional train size=47 loss=3.1961 acc=12.50
# [Client 8] Local test BEFORE aggregation = 6.12%
# [Client 9] fractional train size=64 loss=1.5652 acc=50.00
# [Client 9] Local test BEFORE aggregation = 29.64%
# [Global model] Accuracy on client 0 test set = 27.85%
# [Global model] Accuracy on client 1 test set = 34.01%
# [Global model] Accuracy on client 2 test set = 12.86%
# [Global model] Accuracy on client 3 test set = 9.42%
# [Global model] Accuracy on client 4 test set = 7.88%
# [Global model] Accuracy on client 5 test set = 52.63%
# [Global model] Accuracy on client 6 test set = 25.35%
# [Global model] Accuracy on client 7 test set = 30.92%
# [Global model] Accuracy on client 8 test set = 4.08%
# [Global model] Accuracy on client 9 test set = 36.83%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 27/100 ========
# [Client 0] fractional train size=16 loss=2.3398 acc=12.50
# [Client 0] Local test BEFORE aggregation = 58.23%
# [Client 1] fractional train size=38 loss=2.1957 acc=28.12
# [Client 1] Local test BEFORE aggregation = 42.13%
# [Client 2] fractional train size=46 loss=2.1493 acc=31.25
# [Client 2] Local test BEFORE aggregation = 34.44%
# [Client 3] fractional train size=43 loss=1.8627 acc=40.62
# [Client 3] Local test BEFORE aggregation = 60.09%
# [Client 4] fractional train size=70 loss=1.9324 acc=48.44
# [Client 4] Local test BEFORE aggregation = 26.36%
# [Client 5] fractional train size=62 loss=1.8631 acc=35.42
# [Client 5] Local test BEFORE aggregation = 40.56%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 26.76%
# [Client 7] fractional train size=79 loss=2.0806 acc=34.38
# [Client 7] Local test BEFORE aggregation = 18.36%
# [Client 8] fractional train size=47 loss=2.8923 acc=18.75
# [Client 8] Local test BEFORE aggregation = 8.16%
# [Client 9] fractional train size=64 loss=1.5731 acc=50.00
# [Client 9] Local test BEFORE aggregation = 48.50%
# [Global model] Accuracy on client 0 test set = 17.72%
# [Global model] Accuracy on client 1 test set = 21.32%
# [Global model] Accuracy on client 2 test set = 7.88%
# [Global model] Accuracy on client 3 test set = 29.15%
# [Global model] Accuracy on client 4 test set = 11.41%
# [Global model] Accuracy on client 5 test set = 36.53%
# [Global model] Accuracy on client 6 test set = 30.99%
# [Global model] Accuracy on client 7 test set = 35.51%
# [Global model] Accuracy on client 8 test set = 5.71%
# [Global model] Accuracy on client 9 test set = 30.24%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 28/100 ========
# [Client 0] fractional train size=16 loss=2.3672 acc=6.25
# [Client 0] Local test BEFORE aggregation = 36.71%
# [Client 1] fractional train size=38 loss=1.7874 acc=43.75
# [Client 1] Local test BEFORE aggregation = 37.06%
# [Client 2] fractional train size=46 loss=2.5716 acc=12.50
# [Client 2] Local test BEFORE aggregation = 24.07%
# [Client 3] fractional train size=43 loss=2.2052 acc=28.12
# [Client 3] Local test BEFORE aggregation = 56.95%
# [Client 4] fractional train size=70 loss=1.9308 acc=37.50
# [Client 4] Local test BEFORE aggregation = 51.09%
# [Client 5] fractional train size=62 loss=1.7084 acc=39.58
# [Client 5] Local test BEFORE aggregation = 41.18%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 30.99%
# [Client 7] fractional train size=79 loss=1.7467 acc=43.75
# [Client 7] Local test BEFORE aggregation = 36.47%
# [Client 8] fractional train size=47 loss=3.1271 acc=12.50
# [Client 8] Local test BEFORE aggregation = 7.76%
# [Client 9] fractional train size=64 loss=1.8716 acc=42.19
# [Client 9] Local test BEFORE aggregation = 44.91%
# [Global model] Accuracy on client 0 test set = 7.59%
# [Global model] Accuracy on client 1 test set = 22.84%
# [Global model] Accuracy on client 2 test set = 6.64%
# [Global model] Accuracy on client 3 test set = 25.11%
# [Global model] Accuracy on client 4 test set = 9.51%
# ...
# [Global model] Accuracy on client 0 test set = 31.65%
# [Global model] Accuracy on client 1 test set = 24.37%
# [Global model] Accuracy on client 2 test set = 10.79%
# [Global model] Accuracy on client 3 test set = 13.45%
# [Global model] Accuracy on client 4 test set = 13.04%
# [Global model] Accuracy on client 5 test set = 42.72%
# [Global model] Accuracy on client 6 test set = 8.45%
# [Global model] Accuracy on client 7 test set = 49.03%
# [Global model] Accuracy on client 8 test set = 2.86%
# [Global model] Accuracy on client 9 test set = 30.54%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 92/100 ========
# [Client 0] fractional train size=16 loss=2.1659 acc=12.50
# [Client 0] Local test BEFORE aggregation = 51.90%
# [Client 1] fractional train size=38 loss=1.6156 acc=50.00
# [Client 1] Local test BEFORE aggregation = 47.21%
# [Client 2] fractional train size=46 loss=2.0947 acc=21.88
# [Client 2] Local test BEFORE aggregation = 36.10%
# [Client 3] fractional train size=43 loss=1.6548 acc=40.62
# [Client 3] Local test BEFORE aggregation = 48.88%
# [Client 4] fractional train size=70 loss=1.4064 acc=54.69
# [Client 4] Local test BEFORE aggregation = 50.27%
# [Client 5] fractional train size=62 loss=1.5848 acc=43.75
# [Client 5] Local test BEFORE aggregation = 43.34%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 9.86%
# [Client 7] fractional train size=79 loss=1.7914 acc=40.62
# [Client 7] Local test BEFORE aggregation = 43.96%
# [Client 8] fractional train size=47 loss=4.3553 acc=9.38
# [Client 8] Local test BEFORE aggregation = 3.27%
# [Client 9] fractional train size=64 loss=1.1679 acc=68.75
# [Client 9] Local test BEFORE aggregation = 62.87%
# [Global model] Accuracy on client 0 test set = 22.78%
# [Global model] Accuracy on client 1 test set = 46.19%
# [Global model] Accuracy on client 2 test set = 17.43%
# [Global model] Accuracy on client 3 test set = 30.94%
# [Global model] Accuracy on client 4 test set = 21.47%
# [Global model] Accuracy on client 5 test set = 48.92%
# [Global model] Accuracy on client 6 test set = 43.66%
# [Global model] Accuracy on client 7 test set = 43.00%
# [Global model] Accuracy on client 8 test set = 4.90%
# [Global model] Accuracy on client 9 test set = 39.22%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 93/100 ========
# [Client 0] fractional train size=16 loss=2.0448 acc=31.25
# [Client 0] Local test BEFORE aggregation = 41.77%
# [Client 1] fractional train size=38 loss=1.7349 acc=46.88
# [Client 1] Local test BEFORE aggregation = 51.27%
# [Client 2] fractional train size=46 loss=2.4812 acc=21.88
# [Client 2] Local test BEFORE aggregation = 35.27%
# [Client 3] fractional train size=43 loss=1.9802 acc=40.62
# [Client 3] Local test BEFORE aggregation = 54.26%
# [Client 4] fractional train size=70 loss=1.2106 acc=64.06
# [Client 4] Local test BEFORE aggregation = 62.23%
# [Client 5] fractional train size=62 loss=1.5297 acc=43.75
# [Client 5] Local test BEFORE aggregation = 41.80%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 32.39%
# [Client 7] fractional train size=79 loss=1.5142 acc=50.00
# [Client 7] Local test BEFORE aggregation = 41.79%
# [Client 8] fractional train size=47 loss=4.4840 acc=25.00
# [Client 8] Local test BEFORE aggregation = 7.35%
# [Client 9] fractional train size=64 loss=1.5282 acc=53.12
# [Client 9] Local test BEFORE aggregation = 67.07%
# [Global model] Accuracy on client 0 test set = 32.91%
# [Global model] Accuracy on client 1 test set = 46.19%
# [Global model] Accuracy on client 2 test set = 13.69%
# [Global model] Accuracy on client 3 test set = 39.01%
# [Global model] Accuracy on client 4 test set = 23.91%
# [Global model] Accuracy on client 5 test set = 39.32%
# [Global model] Accuracy on client 6 test set = 36.62%
# [Global model] Accuracy on client 7 test set = 43.72%
# [Global model] Accuracy on client 8 test set = 4.90%
# [Global model] Accuracy on client 9 test set = 42.22%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 94/100 ========
# [Client 0] fractional train size=16 loss=2.3660 acc=12.50
# [Client 0] Local test BEFORE aggregation = 54.43%
# [Client 1] fractional train size=38 loss=1.6040 acc=28.12
# [Client 1] Local test BEFORE aggregation = 45.18%
# [Client 2] fractional train size=46 loss=2.0531 acc=37.50
# [Client 2] Local test BEFORE aggregation = 20.33%
# [Client 3] fractional train size=43 loss=1.9192 acc=46.88
# [Client 3] Local test BEFORE aggregation = 65.92%
# [Client 4] fractional train size=70 loss=1.6639 acc=57.81
# [Client 4] Local test BEFORE aggregation = 67.12%
# [Client 5] fractional train size=62 loss=1.1866 acc=56.25
# [Client 5] Local test BEFORE aggregation = 50.77%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 33.80%
# [Client 7] fractional train size=79 loss=1.6861 acc=43.75
# [Client 7] Local test BEFORE aggregation = 49.76%
# [Client 8] fractional train size=47 loss=3.3641 acc=25.00
# [Client 8] Local test BEFORE aggregation = 3.67%
# [Client 9] fractional train size=64 loss=0.9626 acc=67.19
# [Client 9] Local test BEFORE aggregation = 55.99%
# [Global model] Accuracy on client 0 test set = 31.65%
# [Global model] Accuracy on client 1 test set = 31.47%
# [Global model] Accuracy on client 2 test set = 7.88%
# [Global model] Accuracy on client 3 test set = 26.91%
# [Global model] Accuracy on client 4 test set = 18.75%
# [Global model] Accuracy on client 5 test set = 51.39%
# [Global model] Accuracy on client 6 test set = 11.27%
# [Global model] Accuracy on client 7 test set = 55.07%
# [Global model] Accuracy on client 8 test set = 4.08%
# [Global model] Accuracy on client 9 test set = 34.73%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 95/100 ========
# [Client 0] fractional train size=16 loss=2.5541 acc=12.50
# [Client 0] Local test BEFORE aggregation = 37.97%
# [Client 1] fractional train size=38 loss=1.6859 acc=21.88
# [Client 1] Local test BEFORE aggregation = 34.52%
# [Client 2] fractional train size=46 loss=2.6079 acc=28.12
# [Client 2] Local test BEFORE aggregation = 39.83%
# [Client 3] fractional train size=43 loss=1.8656 acc=31.25
# [Client 3] Local test BEFORE aggregation = 67.71%
# [Client 4] fractional train size=70 loss=1.6203 acc=53.12
# [Client 4] Local test BEFORE aggregation = 68.75%
# [Client 5] fractional train size=62 loss=1.5314 acc=47.92
# [Client 5] Local test BEFORE aggregation = 47.99%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 9.86%
# [Client 7] fractional train size=79 loss=1.6016 acc=48.44
# [Client 7] Local test BEFORE aggregation = 48.55%
# [Client 8] fractional train size=47 loss=4.2144 acc=18.75
# [Client 8] Local test BEFORE aggregation = 6.53%
# [Client 9] fractional train size=64 loss=1.5999 acc=54.69
# [Client 9] Local test BEFORE aggregation = 55.99%
# [Global model] Accuracy on client 0 test set = 31.65%
# [Global model] Accuracy on client 1 test set = 32.49%
# [Global model] Accuracy on client 2 test set = 17.84%
# [Global model] Accuracy on client 3 test set = 27.35%
# [Global model] Accuracy on client 4 test set = 31.25%
# [Global model] Accuracy on client 5 test set = 41.18%
# [Global model] Accuracy on client 6 test set = 16.90%
# [Global model] Accuracy on client 7 test set = 51.93%
# [Global model] Accuracy on client 8 test set = 3.27%
# [Global model] Accuracy on client 9 test set = 32.04%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 96/100 ========
# [Client 0] fractional train size=16 loss=2.1933 acc=18.75
# [Client 0] Local test BEFORE aggregation = 51.90%
# [Client 1] fractional train size=38 loss=1.8480 acc=31.25
# [Client 1] Local test BEFORE aggregation = 47.72%
# [Client 2] fractional train size=46 loss=2.6668 acc=18.75
# [Client 2] Local test BEFORE aggregation = 27.80%
# [Client 3] fractional train size=43 loss=1.8069 acc=28.12
# [Client 3] Local test BEFORE aggregation = 73.09%
# [Client 4] fractional train size=70 loss=1.3573 acc=60.94
# [Client 4] Local test BEFORE aggregation = 62.50%
# [Client 5] fractional train size=62 loss=1.7654 acc=39.58
# [Client 5] Local test BEFORE aggregation = 40.56%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 18.31%
# [Client 7] fractional train size=79 loss=1.3729 acc=54.69
# [Client 7] Local test BEFORE aggregation = 43.72%
# [Client 8] fractional train size=47 loss=4.2604 acc=3.12
# [Client 8] Local test BEFORE aggregation = 4.90%
# [Client 9] fractional train size=64 loss=1.3662 acc=57.81
# [Client 9] Local test BEFORE aggregation = 52.99%
# [Global model] Accuracy on client 0 test set = 35.44%
# [Global model] Accuracy on client 1 test set = 29.44%
# [Global model] Accuracy on client 2 test set = 9.96%
# [Global model] Accuracy on client 3 test set = 16.59%
# [Global model] Accuracy on client 4 test set = 23.64%
# [Global model] Accuracy on client 5 test set = 44.27%
# [Global model] Accuracy on client 6 test set = 11.27%
# [Global model] Accuracy on client 7 test set = 51.69%
# [Global model] Accuracy on client 8 test set = 1.63%
# [Global model] Accuracy on client 9 test set = 35.33%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 97/100 ========
# [Client 0] fractional train size=16 loss=2.2965 acc=18.75
# [Client 0] Local test BEFORE aggregation = 50.63%
# [Client 1] fractional train size=38 loss=1.5333 acc=40.62
# [Client 1] Local test BEFORE aggregation = 41.62%
# [Client 2] fractional train size=46 loss=2.3267 acc=18.75
# [Client 2] Local test BEFORE aggregation = 34.85%
# [Client 3] fractional train size=43 loss=2.0403 acc=40.62
# [Client 3] Local test BEFORE aggregation = 39.91%
# [Client 4] fractional train size=70 loss=1.3746 acc=51.56
# [Client 4] Local test BEFORE aggregation = 64.13%
# [Client 5] fractional train size=62 loss=1.6043 acc=45.83
# [Client 5] Local test BEFORE aggregation = 45.20%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 9.86%
# [Client 7] fractional train size=79 loss=1.8916 acc=40.62
# [Client 7] Local test BEFORE aggregation = 37.92%
# [Client 8] fractional train size=47 loss=3.8456 acc=18.75
# [Client 8] Local test BEFORE aggregation = 5.71%
# [Client 9] fractional train size=64 loss=1.4777 acc=57.81
# [Client 9] Local test BEFORE aggregation = 60.78%
# [Global model] Accuracy on client 0 test set = 35.44%
# [Global model] Accuracy on client 1 test set = 49.75%
# [Global model] Accuracy on client 2 test set = 17.84%
# [Global model] Accuracy on client 3 test set = 33.18%
# [Global model] Accuracy on client 4 test set = 18.21%
# [Global model] Accuracy on client 5 test set = 48.92%
# [Global model] Accuracy on client 6 test set = 33.80%
# [Global model] Accuracy on client 7 test set = 46.38%
# [Global model] Accuracy on client 8 test set = 6.94%
# [Global model] Accuracy on client 9 test set = 46.71%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 98/100 ========
# [Client 0] fractional train size=16 loss=2.1398 acc=37.50
# [Client 0] Local test BEFORE aggregation = 48.10%
# [Client 1] fractional train size=38 loss=1.7968 acc=31.25
# [Client 1] Local test BEFORE aggregation = 47.21%
# [Client 2] fractional train size=46 loss=1.8939 acc=28.12
# [Client 2] Local test BEFORE aggregation = 36.51%
# [Client 3] fractional train size=43 loss=1.7892 acc=40.62
# [Client 3] Local test BEFORE aggregation = 60.54%
# [Client 4] fractional train size=70 loss=1.4267 acc=60.94
# [Client 4] Local test BEFORE aggregation = 54.35%
# [Client 5] fractional train size=62 loss=1.5873 acc=47.92
# [Client 5] Local test BEFORE aggregation = 47.68%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 30.99%
# [Client 7] fractional train size=79 loss=1.7075 acc=48.44
# [Client 7] Local test BEFORE aggregation = 47.34%
# [Client 8] fractional train size=47 loss=4.9485 acc=9.38
# [Client 8] Local test BEFORE aggregation = 30.61%
# [Client 9] fractional train size=64 loss=1.2383 acc=62.50
# [Client 9] Local test BEFORE aggregation = 68.56%
# [Global model] Accuracy on client 0 test set = 29.11%
# [Global model] Accuracy on client 1 test set = 40.61%
# [Global model] Accuracy on client 2 test set = 7.88%
# [Global model] Accuracy on client 3 test set = 25.11%
# [Global model] Accuracy on client 4 test set = 21.74%
# [Global model] Accuracy on client 5 test set = 52.32%
# [Global model] Accuracy on client 6 test set = 15.49%
# [Global model] Accuracy on client 7 test set = 52.90%
# [Global model] Accuracy on client 8 test set = 5.31%
# [Global model] Accuracy on client 9 test set = 40.72%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 99/100 ========
# [Client 0] fractional train size=16 loss=2.1670 acc=31.25
# [Client 0] Local test BEFORE aggregation = 27.85%
# [Client 1] fractional train size=38 loss=1.4342 acc=56.25
# [Client 1] Local test BEFORE aggregation = 45.69%
# [Client 2] fractional train size=46 loss=2.2180 acc=12.50
# [Client 2] Local test BEFORE aggregation = 35.27%
# [Client 3] fractional train size=43 loss=1.9679 acc=31.25
# [Client 3] Local test BEFORE aggregation = 72.65%
# [Client 4] fractional train size=70 loss=1.6216 acc=51.56
# [Client 4] Local test BEFORE aggregation = 45.38%
# [Client 5] fractional train size=62 loss=1.6039 acc=37.50
# [Client 5] Local test BEFORE aggregation = 33.75%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 18.31%
# [Client 7] fractional train size=79 loss=1.4053 acc=57.81
# [Client 7] Local test BEFORE aggregation = 38.16%
# [Client 8] fractional train size=47 loss=5.3173 acc=3.12
# [Client 8] Local test BEFORE aggregation = 5.31%
# [Client 9] fractional train size=64 loss=1.4700 acc=57.81
# [Client 9] Local test BEFORE aggregation = 55.39%
# [Global model] Accuracy on client 0 test set = 35.44%
# [Global model] Accuracy on client 1 test set = 37.56%
# [Global model] Accuracy on client 2 test set = 12.45%
# [Global model] Accuracy on client 3 test set = 35.43%
# [Global model] Accuracy on client 4 test set = 19.84%
# [Global model] Accuracy on client 5 test set = 53.87%
# [Global model] Accuracy on client 6 test set = 19.72%
# [Global model] Accuracy on client 7 test set = 50.24%
# [Global model] Accuracy on client 8 test set = 4.49%
# [Global model] Accuracy on client 9 test set = 35.03%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# ======== ROUND 100/100 ========
# [Client 0] fractional train size=16 loss=1.8452 acc=43.75
# [Client 0] Local test BEFORE aggregation = 39.24%
# [Client 1] fractional train size=38 loss=1.6468 acc=37.50
# [Client 1] Local test BEFORE aggregation = 43.15%
# [Client 2] fractional train size=46 loss=2.2896 acc=25.00
# [Client 2] Local test BEFORE aggregation = 30.29%
# [Client 3] fractional train size=43 loss=1.8776 acc=46.88
# [Client 3] Local test BEFORE aggregation = 51.12%
# [Client 4] fractional train size=70 loss=1.2471 acc=56.25
# [Client 4] Local test BEFORE aggregation = 51.90%
# [Client 5] fractional train size=62 loss=1.6320 acc=45.83
# [Client 5] Local test BEFORE aggregation = 52.94%
# [Client 6] fractional train size=14 loss=0.0000 acc=0.00
# [Client 6] Local test BEFORE aggregation = 23.94%
# [Client 7] fractional train size=79 loss=1.4660 acc=46.88
# [Client 7] Local test BEFORE aggregation = 49.52%
# [Client 8] fractional train size=47 loss=4.6847 acc=9.38
# [Client 8] Local test BEFORE aggregation = 17.14%
# [Client 9] fractional train size=64 loss=1.5937 acc=60.94
# [Client 9] Local test BEFORE aggregation = 58.08%
# [Global model] Accuracy on client 0 test set = 32.91%
# [Global model] Accuracy on client 1 test set = 40.61%
# [Global model] Accuracy on client 2 test set = 9.96%
# [Global model] Accuracy on client 3 test set = 23.77%
# [Global model] Accuracy on client 4 test set = 24.46%
# [Global model] Accuracy on client 5 test set = 49.85%
# [Global model] Accuracy on client 6 test set = 16.90%
# [Global model] Accuracy on client 7 test set = 57.25%
# [Global model] Accuracy on client 8 test set = 2.45%
# [Global model] Accuracy on client 9 test set = 35.93%
# Autosaved to results_cifar10_alpha5_epoch_0_01_new.csv
#
# Training complete. Final CSV saved.

# %%
from google.colab import files
files.download("results_cifar10_alpha5_epoch_0_01_new.csv")
