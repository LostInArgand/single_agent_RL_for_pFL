# %% [markdown]
# # Imports & Config

# %%
# !pip install torch torchvision pandas --quiet

import os
import random
import math
import numpy as np
import pandas as pd
from collections import defaultdict

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, Subset
import torchvision
import torchvision.transforms as T

from google.colab import drive
drive.mount('/content/drive')

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)


# High-level configuration
NUM_CLIENTS     = 10
NUM_ROUNDS      = 100
BATCH_SIZE      = 64
LR_LOCAL        = 0.01
LR_RL           = 0.001
RL_EPSILON      = 1.0
ALPHA_DIRICHLET = 1.0
DATASET_NAME    = "mnist"

EPOCH_ACTION_VALUES = [0.01, 0.1, 0.5, 1.0, 2.0, 5.0]
NUM_EPOCH_ACTIONS   = len(EPOCH_ACTION_VALUES)

LAYER_ACTION_VALUES = [1, 2, 3, 4, 5, 6]
NUM_LAYER_ACTIONS   = len(LAYER_ACTION_VALUES)


CLIENT_CAPABILITIES = np.array(
    [0.5, 0.01, 1.0, 2.0, 2.0, 0.5, 1.0, 2.0, 0.1, 5.0],
    dtype=float
)

COMP_PENALTY_LAMBDA = 1.0

CLIENT_COMM_BUDGETS = np.array(
    [3, 5, 1, 2, 4, 6, 1, 6, 2, 5],
    dtype=float
)

COMM_PENALTY_LAMBDA = 2.0


LOG_DIR = "/content/drive/MyDrive/FL_59500_RL_Logs"
os.makedirs(LOG_DIR, exist_ok=True)
print("Logs will be saved to:", LOG_DIR)
# Out:
# Mounted at /content/drive
# Using device: cuda
# Logs will be saved to: /content/drive/MyDrive/FL_59500_RL_Logs

# %% [markdown]
# # Dataset & non-IID split

# %%
def get_transforms(dataset_name):
    if dataset_name.lower() == "cifar10":
        transform_train = T.Compose([
            T.RandomCrop(32, padding=4),
            T.RandomHorizontalFlip(),
            T.ToTensor(),
            T.Normalize((0.4914, 0.4822, 0.4465),
                        (0.2023, 0.1994, 0.2010))
        ])
        transform_test = T.Compose([
            T.ToTensor(),
            T.Normalize((0.4914, 0.4822, 0.4465),
                        (0.2023, 0.1994, 0.2010))
        ])
    elif dataset_name.lower() == "mnist":
        transform_train = T.Compose([
            T.RandomRotation(10),
            T.ToTensor(),
            T.Normalize((0.1307,), (0.3081,))
        ])
        transform_test = T.Compose([
            T.ToTensor(),
            T.Normalize((0.1307,), (0.3081,))
        ])
    else:
        raise ValueError("Unknown dataset: " + dataset_name)
    return transform_train, transform_test

transform_train, transform_test = get_transforms(DATASET_NAME)

if DATASET_NAME.lower() == "cifar10":
    train_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=True, download=True, transform=transform_train
    )
    test_dataset = torchvision.datasets.CIFAR10(
        root="./data", train=False, download=True, transform=transform_test
    )
    NUM_CLASSES = 10
elif DATASET_NAME.lower() == "mnist":
    train_dataset = torchvision.datasets.MNIST(
        root="./data", train=True, download=True, transform=transform_train
    )
    test_dataset = torchvision.datasets.MNIST(
        root="./data", train=False, download=True, transform=transform_test
    )
    NUM_CLASSES = 10
else:
    raise ValueError("Unknown dataset")

if hasattr(train_dataset, "targets"):
    all_targets = np.array(train_dataset.targets)
elif hasattr(train_dataset, "labels"):
    all_targets = np.array(train_dataset.labels)
else:
    all_targets = np.array([train_dataset[i][1] for i in range(len(train_dataset))])

def iid_split(num_clients, n_samples, seed=42):
    rng = np.random.RandomState(seed)
    indices = np.arange(n_samples)
    rng.shuffle(indices)
    splits = np.array_split(indices, num_clients)
    return [split.tolist() for split in splits]

def dirichlet_split(num_clients, targets, alpha, seed=42):

    rng = np.random.RandomState(seed)
    n_classes = int(targets.max()) + 1
    idx_by_class = {c: np.where(targets == c)[0] for c in range(n_classes)}
    client_indices = [[] for _ in range(num_clients)]

    dirichlet_conc = 1.0 / alpha
    dirichlet_conc = float(np.clip(dirichlet_conc, 1e-3, 1e3))

    for c in range(n_classes):
        idx_c = idx_by_class[c].copy()
        rng.shuffle(idx_c)

        proportions = rng.dirichlet(dirichlet_conc * np.ones(num_clients))
        split_points = (np.cumsum(proportions) * len(idx_c)).astype(int)[:-1]
        class_splits = np.split(idx_c, split_points)

        for i in range(num_clients):
            client_indices[i].extend(class_splits[i].tolist())

    for i in range(num_clients):
        rng.shuffle(client_indices[i])
    return client_indices

if ALPHA_DIRICHLET == 0:
    print("Using IID split")
    client_indices = iid_split(NUM_CLIENTS, len(train_dataset))
else:
    print(f"Using Dirichlet non-IID split, alpha={ALPHA_DIRICHLET} (larger = more non-IID)")
    client_indices = dirichlet_split(NUM_CLIENTS, all_targets, ALPHA_DIRICHLET)


test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=2)


for cid, idxs in enumerate(client_indices):
    print(f"Client {cid}: {len(idxs)} samples")
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.05MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 134kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.27MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 9.11MB/s]
# Using Dirichlet non-IID split, alpha=1.0 (larger = more non-IID)
# Client 0: 6917 samples
# Client 1: 7463 samples
# Client 2: 6669 samples
# Client 3: 4864 samples
# Client 4: 6447 samples
# Client 5: 2824 samples
# Client 6: 5674 samples
# Client 7: 6792 samples
# Client 8: 5194 samples
# Client 9: 7156 samples

# %% [markdown]
# # Model definition & helpers

# %%
def get_model(dataset_name, num_classes):

    base = torchvision.models.resnet18(weights=None)

    if dataset_name.lower() == "mnist":

        base.conv1 = nn.Conv2d(1, 64, kernel_size=3, stride=1,
                               padding=1, bias=False)
        base.maxpool = nn.Identity()
    else:
        base.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1,
                               padding=1, bias=False)
        base.maxpool = nn.Identity()

    in_features = base.fc.in_features
    base.fc = nn.Linear(in_features, num_classes)
    return base.to(device)

def get_model_params_vector(model):

    with torch.no_grad():
        return torch.cat([p.view(-1).cpu() for p in model.parameters()])

def set_model_params(model, global_model):

    model.load_state_dict(global_model.state_dict())

# %% [markdown]
# # Client class

# %%
class FLClient:
    def __init__(self, client_id, dataset, indices, capability, batch_size=64, lr=0.01):
        self.client_id = client_id
        self.dataset = dataset
        self.indices = indices
        self.capability = float(capability)
        self.batch_size = batch_size
        self.lr = lr

        self.data_size = len(indices)

        # Rolling pointer over shuffled local indices
        self.current_perm = np.array(self.indices)
        np.random.shuffle(self.current_perm)
        self.ptr = 0
    def _get_train_indices_for_action(self, action_value):

        total_required = int(round(action_value * self.data_size))
        total_required = max(1, total_required)

        chosen = []

        while len(chosen) < total_required and self.data_size > 0:
            remaining_in_cycle = self.data_size - self.ptr
            need = total_required - len(chosen)
            take = min(remaining_in_cycle, need)

            chosen.extend(self.current_perm[self.ptr: self.ptr + take].tolist())
            self.ptr += take

            if self.ptr >= self.data_size and len(chosen) < total_required:
                np.random.shuffle(self.current_perm)
                self.ptr = 0

        return chosen

    def get_full_train_loader(self):
        subset = Subset(self.dataset, self.indices)
        loader = DataLoader(subset, batch_size=self.batch_size,
                            shuffle=False, num_workers=2)
        return loader

    def get_action_train_loader(self, action_value):
        """
        BN-safe DataLoader for the chosen action_value.
        """
        subset_indices = self._get_train_indices_for_action(action_value)
        subset = Subset(self.dataset, subset_indices)
        n = len(subset_indices)

        if n < 2:
            loader = DataLoader(subset, batch_size=1, shuffle=False, num_workers=0)
            return loader, n

        curr_bs = min(self.batch_size, n)
        loader = DataLoader(
            subset,
            batch_size=curr_bs,
            shuffle=True,
            num_workers=2,
            drop_last=True  # avoid batch_size=1 for BN
        )
        return loader, n

    def local_train(self, model, action_value, device):

        model = model.to(device)

        train_loader, num_samples_used = self.get_action_train_loader(action_value)

        if num_samples_used >= 2:
            model.train()
            optimizer = optim.SGD(model.parameters(), lr=self.lr,
                                  momentum=0.9, weight_decay=5e-4)

            for x, y in train_loader:
                if x.size(0) < 2:
                    continue  # BN safety
                x, y = x.to(device), y.to(device)
                optimizer.zero_grad()
                out = model(x)
                loss = F.cross_entropy(out, y)
                loss.backward()
                optimizer.step()


        model.eval()
        full_loader = self.get_full_train_loader()
        correct = 0
        total = 0
        total_loss = 0.0

        with torch.no_grad():
            for x, y in full_loader:
                x, y = x.to(device), y.to(device)
                out = model(x)
                loss = F.cross_entropy(out, y)
                total_loss += loss.item() * x.size(0)
                preds = out.argmax(dim=1)
                correct += (preds == y).sum().item()
                total += x.size(0)

        local_loss = total_loss / max(1, total)
        local_acc = correct / max(1, total)

        if self.data_size > 0:
            effective_epochs = num_samples_used / float(self.data_size)
        else:
            effective_epochs = 0.0

        return model, local_loss, local_acc, num_samples_used, effective_epochs

# %% [markdown]
# # Server class (Partial sharing + shared-only distance for reward)

# %%
class FLServer:
    def __init__(self, global_model, test_loader, device):
        self.global_model = global_model.to(device)
        self.test_loader = test_loader
        self.device = device

        self.param_keys = list(self.global_model.state_dict().keys())
        self.num_param_keys = len(self.param_keys)

    def aggregate(self, client_models, num_param_to_share_per_client):

        assert len(client_models) == len(num_param_to_share_per_client)
        global_dict = self.global_model.state_dict()

        sum_dict = {k: torch.zeros_like(global_dict[k]) for k in self.param_keys}
        cnt_dict = {k: 0 for k in self.param_keys}

        for cid, model in enumerate(client_models):
            sd = model.state_dict()
            L_i = int(num_param_to_share_per_client[cid])
            L_i = max(0, min(L_i, self.num_param_keys))

            for j in range(L_i):
                k = self.param_keys[j]
                sum_dict[k] += sd[k].to(sum_dict[k].device)
                cnt_dict[k] += 1


        for k in self.param_keys:
            if cnt_dict[k] > 0:
                global_dict[k] = sum_dict[k] / float(cnt_dict[k])
            else:
                pass

        self.global_model.load_state_dict(global_dict)

    def evaluate_global(self):

        self.global_model.eval()
        self.global_model.to(self.device)

        total_loss = 0.0
        total_correct = 0
        total_samples = 0

        with torch.no_grad():
            for x, y in self.test_loader:
                x, y = x.to(self.device), y.to(self.device)
                out = self.global_model(x)
                loss = F.cross_entropy(out, y)
                total_loss += loss.item() * x.size(0)
                preds = out.argmax(dim=1)
                total_correct += (preds == y).sum().item()
                total_samples += x.size(0)

        avg_loss = total_loss / max(1, total_samples)
        avg_acc = total_correct / max(1, total_samples)
        return avg_loss, avg_acc


    def compute_layerwise_avg_distances_from_shared(self, client_models, num_param_to_share_per_client):

        N = len(client_models)
        assert N == len(num_param_to_share_per_client)

        sds = [m.state_dict() for m in client_models]
        Ls  = [int(max(0, min(num_param_to_share_per_client[i], self.num_param_keys))) for i in range(N)]

        layer_avg = np.zeros(self.num_param_keys, dtype=np.float32)

        for j in range(self.num_param_keys):
            shared_ids = [i for i in range(N) if Ls[i] > j]
            m = len(shared_ids)
            if m < 2:
                layer_avg[j] = 0.0
                continue

            k = self.param_keys[j]

            total = 0.0
            cnt = 0

            for a in range(m):
                i = shared_ids[a]
                wi = sds[i][k].detach().view(-1).float().cpu()
                for b in range(a + 1, m):
                    t = shared_ids[b]
                    wt = sds[t][k].detach().view(-1).float().cpu()
                    total += float(torch.norm(wi - wt, p=2).item())
                    cnt += 1

            layer_avg[j] = float(total / max(1, cnt))

        return layer_avg

    def compute_client_shared_distance_for_reward(self, layer_avg, num_param_to_share_per_client):

        N = len(num_param_to_share_per_client)
        client_dist = np.zeros(N, dtype=np.float32)

        for i in range(N):
            L_i = int(max(0, min(num_param_to_share_per_client[i], self.num_param_keys)))
            if L_i <= 0:
                client_dist[i] = 0.0
            else:
                client_dist[i] = float(np.mean(layer_avg[:L_i]))
        return client_dist

    def compute_distance_matrix(self, client_models):

        num_clients = len(client_models)
        vectors = [get_model_params_vector(m) for m in client_models]
        D = np.zeros((num_clients, num_clients), dtype=np.float32)

        for i in range(num_clients):
            for j in range(num_clients):
                if i == j:
                    D[i, j] = 0.0
                else:
                    diff = vectors[i] - vectors[j]
                    D[i, j] = float(torch.norm(diff, p=2).item())

        sum_dist = D.sum(axis=1)
        return D, sum_dist

# %% [markdown]
# # RL Agent

# %%
class RLBanditAgent(nn.Module):

    def __init__(self, num_clients,
                 num_epoch_actions,
                 num_layer_actions,
                 hidden_dim=64,
                 lr=1e-3,
                 epsilon=1.0,
                 eps_min=0.05,
                 eps_decay=0.995,
                 dropout=0.1):
        super().__init__()
        self.num_clients        = num_clients
        self.num_epoch_actions  = num_epoch_actions
        self.num_layer_actions  = num_layer_actions

        # Epsilon-greedy (shared for both heads)
        self.epsilon   = epsilon
        self.eps_min   = eps_min
        self.eps_decay = eps_decay

        # Embedding for client IDs
        self.emb_dim = min(32, hidden_dim)
        self.embed = nn.Embedding(num_clients, self.emb_dim)

        in_dim = self.emb_dim + 2

        # Shared trunk
        self.trunk = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(dropout),
        )

        # Two heads: epochs and layers
        self.head_epoch = nn.Linear(hidden_dim, num_epoch_actions)
        self.head_layer = nn.Linear(hidden_dim, num_layer_actions)

        self.to(device)
        self.optimizer = optim.Adam(self.parameters(), lr=lr)

        self.r_mean = 0.0
        self.r_std  = 1.0
        self.r_beta = 0.01

    def forward(self, client_ids_t, accs_t, caps_t):

        emb = self.embed(client_ids_t)                 # [B, emb_dim]
        ctx = torch.stack([accs_t, caps_t], dim=1)     # [B, 2]
        x = torch.cat([emb, ctx], dim=1)               # [B, emb_dim+2]
        h = self.trunk(x)
        q_epoch = self.head_epoch(h)
        q_layer = self.head_layer(h)
        return q_epoch, q_layer

    def select_actions(self, client_ids, accs, caps):

        client_ids_t = torch.tensor(client_ids, dtype=torch.long, device=device)
        accs_t       = torch.tensor(accs,      dtype=torch.float32, device=device)
        caps_t       = torch.tensor(caps,      dtype=torch.float32, device=device)

        q_epoch, q_layer = self.forward(client_ids_t, accs_t, caps_t)
        B = q_epoch.size(0)

        with torch.no_grad():
            # Greedy actions
            greedy_epoch = torch.argmax(q_epoch, dim=1)   # [B]
            greedy_layer = torch.argmax(q_layer, dim=1)   # [B]

            # Random actions
            random_epoch = torch.randint(0, self.num_epoch_actions, (B,), device=device)
            random_layer = torch.randint(0, self.num_layer_actions, (B,), device=device)

            explore_mask = (torch.rand(B, device=device) < self.epsilon)

            epoch_actions = torch.where(explore_mask, random_epoch, greedy_epoch)
            layer_actions = torch.where(explore_mask, random_layer, greedy_layer)

        return (
            epoch_actions,
            layer_actions,
            q_epoch.detach().cpu().numpy(),
            q_layer.detach().cpu().numpy()
        )

    def _update_reward_stats(self, rewards_t):
        batch_mean = rewards_t.mean().item()
        batch_std  = rewards_t.std(unbiased=False).item()
        if batch_std < 1e-6:
            batch_std = 1.0

        self.r_mean = (1 - self.r_beta) * self.r_mean + self.r_beta * batch_mean
        self.r_std  = (1 - self.r_beta) * self.r_std  + self.r_beta * batch_std

    def update(self, client_ids, accs, caps,
               epoch_actions, layer_actions, rewards):
        """
        One-step Q regression for both heads:
            Q_epoch(s,a_e) ≈ normalized reward
            Q_layer(s,a_l) ≈ normalized reward
        """
        self.optimizer.zero_grad()

        client_ids_t = torch.tensor(client_ids,    dtype=torch.long,   device=device)
        accs_t       = torch.tensor(accs,          dtype=torch.float32, device=device)
        caps_t       = torch.tensor(caps,          dtype=torch.float32, device=device)
        epoch_act_t  = torch.tensor(epoch_actions, dtype=torch.long,   device=device)
        layer_act_t  = torch.tensor(layer_actions, dtype=torch.long,   device=device)
        rewards_t    = torch.tensor(rewards,       dtype=torch.float32, device=device)

        # Normalize rewards
        self._update_reward_stats(rewards_t)
        norm_rewards = (rewards_t - self.r_mean) / (self.r_std + 1e-6)

        q_epoch, q_layer = self.forward(client_ids_t, accs_t, caps_t)

        q_epoch_sel = q_epoch[torch.arange(len(epoch_actions), device=device), epoch_act_t]
        q_layer_sel = q_layer[torch.arange(len(layer_actions), device=device), layer_act_t]

        loss_epoch = F.smooth_l1_loss(q_epoch_sel, norm_rewards)
        loss_layer = F.smooth_l1_loss(q_layer_sel, norm_rewards)
        loss = 0.5 * (loss_epoch + loss_layer)

        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm=5.0)
        self.optimizer.step()

        # decay epsilon
        self.epsilon = max(self.eps_min, self.epsilon * self.eps_decay)

        return loss.item()

# %% [markdown]
# # Main training loop

# %%
def compute_comp_penalty(capability, requested_epochs):
    """
    Penalize ONLY compute overuse based on requested epochs:
      exceed = max(0, requested_epochs - capability)
      penalty = COMP_PENALTY_LAMBDA * exceed
    """
    capability = float(capability)
    requested_epochs = float(requested_epochs)
    exceed = max(0.0, requested_epochs - capability)
    return float(COMP_PENALTY_LAMBDA) * float(exceed)

def compute_comm_penalty(requested_layers, comm_budget_layers):
    """
    Penalize ONLY comm overuse in layers:
      exceed = max(0, requested_layers - comm_budget_layers)
      penalty = COMM_PENALTY_LAMBDA * exceed
    """
    requested_layers = int(requested_layers)
    comm_budget_layers = int(comm_budget_layers)
    exceed = max(0, requested_layers - comm_budget_layers)
    return float(COMM_PENALTY_LAMBDA) * float(exceed), int(exceed)

def evaluate_model_on_test(model, test_loader, device):
    """
    Evaluate a given model on the global TEST set.
    Returns (test_loss, test_accuracy).
    """
    model.eval()
    model.to(device)

    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            out = model(x)
            loss = F.cross_entropy(out, y)
            total_loss += loss.item() * x.size(0)
            preds = out.argmax(dim=1)
            total_correct += (preds == y).sum().item()
            total_samples += x.size(0)

    avg_loss = total_loss / max(1, total_samples)
    avg_acc  = total_correct / max(1, total_samples)
    return float(avg_loss), float(avg_acc)

# 1) Build global model
global_model = get_model(DATASET_NAME, NUM_CLASSES).to(device)

# 2) Build clients
clients = []
for cid in range(NUM_CLIENTS):
    cap = CLIENT_CAPABILITIES[cid]
    c = FLClient(
        client_id=cid,
        dataset=train_dataset,
        indices=client_indices[cid],
        capability=cap,
        batch_size=BATCH_SIZE,
        lr=LR_LOCAL
    )
    clients.append(c)

# 3) Build server
server = FLServer(global_model=global_model, test_loader=test_loader, device=device)


NUM_PARAM_KEYS = server.num_param_keys
PARAM_KEYS     = server.param_keys

def apply_partial_global_to_client(client_model, global_model, num_param_keys, param_keys):

    client_sd = client_model.state_dict()
    global_sd = global_model.state_dict()

    L = int(max(0, min(num_param_keys, len(param_keys))))
    for j in range(L):
        k = param_keys[j]
        client_sd[k] = global_sd[k].clone()

    client_model.load_state_dict(client_sd)

agent = RLBanditAgent(
    num_clients=NUM_CLIENTS,
    num_epoch_actions=NUM_EPOCH_ACTIONS,
    num_layer_actions=NUM_LAYER_ACTIONS,
    hidden_dim=32,
    lr=LR_RL,
    epsilon=RL_EPSILON
)


global_log   = []
client_log   = []
distance_log = []

client_models = []
for cid in range(NUM_CLIENTS):
    m = get_model(DATASET_NAME, NUM_CLASSES)
    set_model_params(m, server.global_model)
    client_models.append(m)

prev_local_accs  = np.zeros(NUM_CLIENTS, dtype=np.float32)
client_caps_list = CLIENT_CAPABILITIES.astype(np.float32).tolist()

for rnd in range(1, NUM_ROUNDS + 1):
    print(f"\n===== Round {rnd} =====")

    local_losses         = []
    local_accs           = []
    num_used_list        = []
    eff_epochs_list      = []
    num_params_shared    = []
    epoch_action_indices = []
    layer_action_indices = []

    # ------- RL: select 2 actions per client -------
    client_ids_list = list(range(NUM_CLIENTS))
    epoch_actions_t, layer_actions_t, q_epoch_np, q_layer_np = agent.select_actions(
        client_ids=client_ids_list,
        accs=prev_local_accs,
        caps=client_caps_list
    )

    epoch_actions = epoch_actions_t.cpu().numpy()
    layer_actions = layer_actions_t.cpu().numpy()

    models_for_agg = []


    for cid, client in enumerate(clients):
        local_model = client_models[cid]


        epoch_idx   = int(epoch_actions[cid])
        epoch_value = float(EPOCH_ACTION_VALUES[epoch_idx])


        layer_idx   = int(layer_actions[cid])
        layer_val   = int(LAYER_ACTION_VALUES[layer_idx])
        num_share   = int(max(1, min(layer_val, NUM_PARAM_KEYS)))


        apply_partial_global_to_client(
            client_model=local_model,
            global_model=server.global_model,
            num_param_keys=num_share,
            param_keys=PARAM_KEYS
        )


        updated_model, local_loss, local_acc, num_used, eff_epochs = client.local_train(
            model=local_model,
            action_value=epoch_value,
            device=device
        )

        client_models[cid] = updated_model
        models_for_agg.append(updated_model)

        local_losses.append(float(local_loss))
        local_accs.append(float(local_acc))
        num_used_list.append(int(num_used))
        eff_epochs_list.append(float(eff_epochs))
        num_params_shared.append(int(num_share))
        epoch_action_indices.append(int(epoch_idx))
        layer_action_indices.append(int(layer_idx))

        print(
            f"Client {cid}: epoch_action={epoch_value}, "
            f"layer_action_value={layer_val} -> shared_params={num_share}, "
            f"loss={local_loss:.4f}, acc={local_acc:.4f}, "
            f"used={num_used}, eff_epochs={eff_epochs:.3f}"
        )


    server.aggregate(models_for_agg, num_param_to_share_per_client=num_params_shared)


    global_test_loss, global_test_acc = server.evaluate_global()
    print(f"Global-like model test accuracy: {global_test_acc:.4f}, loss: {global_test_loss:.4f}")

    layer_avg = server.compute_layerwise_avg_distances_from_shared(
        client_models=models_for_agg,
        num_param_to_share_per_client=num_params_shared
    )
    client_shared_dist = server.compute_client_shared_distance_for_reward(
        layer_avg=layer_avg,
        num_param_to_share_per_client=num_params_shared
    )


    client_test_losses = []
    client_test_accs   = []
    for cid in range(NUM_CLIENTS):
        tl, ta = evaluate_model_on_test(client_models[cid], test_loader, device)
        client_test_losses.append(float(tl))
        client_test_accs.append(float(ta))
        print(f"Client {cid}: test_acc={ta:.4f}, test_loss={tl:.4f}")

    avg_client_test_acc  = float(np.mean(client_test_accs))
    avg_client_test_loss = float(np.mean(client_test_losses))
    print(f"Average client test accuracy: {avg_client_test_acc:.4f}, "
          f"Average client test loss: {avg_client_test_loss:.4f}")

    rewards            = []
    comp_penalties     = []
    comm_penalties     = []
    exceed_layer_counts = []

    for cid in range(NUM_CLIENTS):
        acc_i   = float(local_accs[cid])
        cap_i   = float(CLIENT_CAPABILITIES[cid])

        # requested action values
        epoch_idx   = int(epoch_action_indices[cid])
        epoch_value = float(EPOCH_ACTION_VALUES[epoch_idx])

        shared_layers = int(num_params_shared[cid])
        pref_layers   = int(CLIENT_COMM_BUDGETS[cid])

        # penalties
        comp_penalty = compute_comp_penalty(cap_i, epoch_value)
        comm_penalty, exceed_layers = compute_comm_penalty(shared_layers, pref_layers)

        # shared-only distance term (already averaged by layers shared)
        dist_i = float(client_shared_dist[cid])

        # reward
        reward_i = acc_i + cap_i - dist_i - comp_penalty - comm_penalty

        rewards.append(float(reward_i))
        comp_penalties.append(float(comp_penalty))
        comm_penalties.append(float(comm_penalty))
        exceed_layer_counts.append(int(exceed_layers))

        print(
            f"Client {cid}: reward={reward_i:.4f} "
            f"(local_acc={acc_i:.4f}, cap={cap_i:.2f}, "
            f"shared_dist={dist_i:.4f}, "
            f"epoch_req={epoch_value:.3f}, comp_penalty={comp_penalty:.4f}, "
            f"shared_layers={shared_layers}, pref_layers={pref_layers}, "
            f"exceed_layers={exceed_layers}, comm_penalty={comm_penalty:.4f})"
        )

    # ------- RL update -------
    rl_loss = agent.update(
        client_ids=client_ids_list,
        accs=prev_local_accs,
        caps=client_caps_list,
        epoch_actions=epoch_actions,
        layer_actions=layer_actions,
        rewards=rewards
    )
    print(f"RL loss: {rl_loss:.4f}")

    # Update RL state
    prev_local_accs = np.array(local_accs, dtype=np.float32)

    # ------- Logging (per client) -------
    for cid in range(NUM_CLIENTS):
        epoch_idx = int(epoch_action_indices[cid])
        layer_idx = int(layer_action_indices[cid])

        layer_val   = int(LAYER_ACTION_VALUES[layer_idx])
        num_share   = int(num_params_shared[cid])
        pref_layers = int(CLIENT_COMM_BUDGETS[cid])

        row = {
            "round": rnd,
            "client_id": cid,

            # Local train
            "local_loss": float(local_losses[cid]),
            "local_acc": float(local_accs[cid]),

            # Client global test
            "client_test_loss": float(client_test_losses[cid]),
            "client_test_acc": float(client_test_accs[cid]),

            # Budgets
            "capability": float(CLIENT_CAPABILITIES[cid]),
            "comm_budget_layers": float(CLIENT_COMM_BUDGETS[cid]),

            # State
            "last_acc_state": float(prev_local_accs[cid]),

            # Actions
            "epoch_action_index": int(epoch_idx),
            "epoch_action_value": float(EPOCH_ACTION_VALUES[epoch_idx]),
            "layer_action_index": int(layer_idx),
            "layer_action_value": int(layer_val),

            # Sharing stats
            "num_param_keys_shared": int(num_share),
            "preferred_layers": int(pref_layers),
            "exceed_layers": int(exceed_layer_counts[cid]),

            # Shared-only distance used for reward
            "shared_dist_reward": float(client_shared_dist[cid]),

            # Penalties + reward
            "comp_penalty": float(comp_penalties[cid]),
            "comm_penalty": float(comm_penalties[cid]),
            "reward": float(rewards[cid]),
        }

        for a_idx, q in enumerate(q_epoch_np[cid]):
            row[f"Q_epoch_action_{a_idx}"] = float(q)

        for a_idx, q in enumerate(q_layer_np[cid]):
            row[f"Q_layer_action_{a_idx}"] = float(q)

        client_log.append(row)

    # ------- Logging (per round) -------
    global_log.append({
        "round": rnd,
        "global_test_loss": float(global_test_loss),
        "global_test_acc": float(global_test_acc),
        "avg_client_test_loss": float(avg_client_test_loss),
        "avg_client_test_acc": float(avg_client_test_acc),
    })
# Out:
# ===== Round 1 =====
# Client 0: epoch_action=0.1, layer_action_value=4 -> shared_params=4, loss=1.6766, acc=0.4204, used=692, eff_epochs=0.100
# Client 1: epoch_action=0.1, layer_action_value=1 -> shared_params=1, loss=2.0107, acc=0.2642, used=746, eff_epochs=0.100
# Client 2: epoch_action=0.1, layer_action_value=6 -> shared_params=6, loss=1.8860, acc=0.3890, used=667, eff_epochs=0.100
# Client 3: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.1694, acc=0.9453, used=9728, eff_epochs=2.000
# Client 4: epoch_action=0.1, layer_action_value=6 -> shared_params=6, loss=1.9592, acc=0.3371, used=645, eff_epochs=0.100
# Client 5: epoch_action=0.01, layer_action_value=1 -> shared_params=1, loss=2.1635, acc=0.2836, used=28, eff_epochs=0.010
# Client 6: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.1582, acc=0.9544, used=11348, eff_epochs=2.000
# Client 7: epoch_action=2.0, layer_action_value=2 -> shared_params=2, loss=0.0972, acc=0.9738, used=13584, eff_epochs=2.000
# Client 8: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0297, acc=0.9894, used=25970, eff_epochs=5.000
# Client 9: epoch_action=5.0, layer_action_value=4 -> shared_params=4, loss=0.0187, acc=0.9948, used=35780, eff_epochs=5.000
# Global-like model test accuracy: 0.0846, loss: 2.9345
# Client 0: test_acc=0.1899, test_loss=3.0551
# Client 1: test_acc=0.1777, test_loss=2.4745
# Client 2: test_acc=0.1862, test_loss=2.6334
# Client 3: test_acc=0.8682, test_loss=0.3987
# Client 4: test_acc=0.1344, test_loss=3.7002
# Client 5: test_acc=0.0980, test_loss=2.5102
# Client 6: test_acc=0.7733, test_loss=0.6042
# Client 7: test_acc=0.8491, test_loss=0.5719
# Client 8: test_acc=0.9680, test_loss=0.0994
# Client 9: test_acc=0.9759, test_loss=0.0767
# Average client test accuracy: 0.5221, Average client test loss: 1.6124
# Client 0: reward=-1.2590 (local_acc=0.4204, cap=0.50, shared_dist=0.1794, epoch_req=0.100, comp_penalty=0.0000, shared_layers=4, pref_layers=3, exceed_layers=1, comm_penalty=2.0000)
# Client 1: reward=-0.1698 (local_acc=0.2642, cap=0.01, shared_dist=0.3540, epoch_req=0.100, comp_penalty=0.0900, shared_layers=1, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-8.9668 (local_acc=0.3890, cap=1.00, shared_dist=0.3557, epoch_req=0.100, comp_penalty=0.0000, shared_layers=6, pref_layers=1, exceed_layers=5, comm_penalty=10.0000)
# Client 3: reward=-3.4816 (local_acc=0.9453, cap=2.00, shared_dist=0.4269, epoch_req=2.000, comp_penalty=0.0000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 4: reward=-2.0187 (local_acc=0.3371, cap=2.00, shared_dist=0.3557, epoch_req=0.100, comp_penalty=0.0000, shared_layers=6, pref_layers=4, exceed_layers=2, comm_penalty=4.0000)
# Client 5: reward=0.4296 (local_acc=0.2836, cap=0.50, shared_dist=0.3540, epoch_req=0.010, comp_penalty=0.0000, shared_layers=1, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-7.4725 (local_acc=0.9544, cap=1.00, shared_dist=0.4269, epoch_req=2.000, comp_penalty=1.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 7: reward=2.7392 (local_acc=0.9738, cap=2.00, shared_dist=0.2346, epoch_req=2.000, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-4.0452 (local_acc=0.9894, cap=0.10, shared_dist=0.2346, epoch_req=5.000, comp_penalty=4.9000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.8154 (local_acc=0.9948, cap=5.00, shared_dist=0.1794, epoch_req=5.000, comp_penalty=0.0000, shared_layers=4, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 3.1162
#
# ===== Round 2 =====
# Client 0: epoch_action=5.0, layer_action_value=6 -> shared_params=6, loss=0.0236, acc=0.9933, used=34585, eff_epochs=5.000
# Client 1: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.3054, acc=0.9114, used=3732, eff_epochs=0.500
# Client 2: epoch_action=0.01, layer_action_value=4 -> shared_params=4, loss=1.8420, acc=0.5005, used=67, eff_epochs=0.010
# Client 3: epoch_action=2.0, layer_action_value=1 -> shared_params=1, loss=0.0669, acc=0.9794, used=9728, eff_epochs=2.000
# Client 4: epoch_action=0.01, layer_action_value=2 -> shared_params=2, loss=1.5159, acc=0.5049, used=64, eff_epochs=0.010
# Client 5: epoch_action=2.0, layer_action_value=2 -> shared_params=2, loss=0.1730, acc=0.9518, used=5648, eff_epochs=2.000
# Client 6: epoch_action=5.0, layer_action_value=4 -> shared_params=4, loss=0.0082, acc=0.9986, used=28370, eff_epochs=5.000
# Client 7: epoch_action=1.0, layer_action_value=2 -> shared_params=2, loss=0.0622, acc=0.9788, used=6792, eff_epochs=1.000
# Client 8: epoch_action=0.01, layer_action_value=6 -> shared_params=6, loss=0.3594, acc=0.8695, used=52, eff_epochs=0.010
# Client 9: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0100, acc=0.9979, used=3578, eff_epochs=0.500
# Global-like model test accuracy: 0.0848, loss: 3.0347
# Client 0: test_acc=0.9053, test_loss=0.3077
# Client 1: test_acc=0.8226, test_loss=0.5373
# Client 2: test_acc=0.2851, test_loss=2.4924
# Client 3: test_acc=0.9386, test_loss=0.1914
# Client 4: test_acc=0.1751, test_loss=3.3407
# Client 5: test_acc=0.7542, test_loss=0.6192
# Client 6: test_acc=0.9411, test_loss=0.1806
# Client 7: test_acc=0.8490, test_loss=0.4484
# Client 8: test_acc=0.8698, test_loss=0.4061
# Client 9: test_acc=0.9805, test_loss=0.0649
# Average client test accuracy: 0.7521, Average client test loss: 0.8589
# Client 0: reward=-99.1203 (local_acc=0.9933, cap=0.50, shared_dist=90.1136, epoch_req=5.000, comp_penalty=4.5000, shared_layers=6, pref_layers=3, exceed_layers=3, comm_penalty=6.0000)
# Client 1: reward=0.3033 (local_acc=0.9114, cap=0.01, shared_dist=0.1281, epoch_req=0.500, comp_penalty=0.4900, shared_layers=4, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-4.6276 (local_acc=0.5005, cap=1.00, shared_dist=0.1281, epoch_req=0.010, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 3: reward=2.7257 (local_acc=0.9794, cap=2.00, shared_dist=0.2537, epoch_req=2.000, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.3280 (local_acc=0.5049, cap=2.00, shared_dist=0.1769, epoch_req=0.010, comp_penalty=0.0000, shared_layers=2, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=-0.2250 (local_acc=0.9518, cap=0.50, shared_dist=0.1769, epoch_req=2.000, comp_penalty=1.5000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-8.1295 (local_acc=0.9986, cap=1.00, shared_dist=0.1281, epoch_req=5.000, comp_penalty=4.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 7: reward=2.8019 (local_acc=0.9788, cap=2.00, shared_dist=0.1769, epoch_req=1.000, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-97.1442 (local_acc=0.8695, cap=0.10, shared_dist=90.1136, epoch_req=0.010, comp_penalty=0.0000, shared_layers=6, pref_layers=2, exceed_layers=4, comm_penalty=8.0000)
# Client 9: reward=5.8698 (local_acc=0.9979, cap=5.00, shared_dist=0.1281, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 15.3418
#
# ===== Round 3 =====
# Client 0: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0160, acc=0.9962, used=692, eff_epochs=0.100
# Client 1: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.1560, acc=0.9562, used=3732, eff_epochs=0.500
# Client 2: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.4267, acc=0.8665, used=3334, eff_epochs=0.500
# Client 3: epoch_action=0.5, layer_action_value=6 -> shared_params=6, loss=0.0380, acc=0.9899, used=2432, eff_epochs=0.500
# Client 4: epoch_action=0.01, layer_action_value=2 -> shared_params=2, loss=1.2875, acc=0.6192, used=64, eff_epochs=0.010
# Client 5: epoch_action=0.01, layer_action_value=2 -> shared_params=2, loss=0.1528, acc=0.9614, used=28, eff_epochs=0.010
# Client 6: epoch_action=0.01, layer_action_value=6 -> shared_params=6, loss=0.0380, acc=0.9907, used=57, eff_epochs=0.010
# Client 7: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.0429, acc=0.9876, used=13584, eff_epochs=2.000
# Client 8: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0072, acc=0.9981, used=25970, eff_epochs=5.000
# Client 9: epoch_action=5.0, layer_action_value=5 -> shared_params=5, loss=0.0046, acc=0.9997, used=35780, eff_epochs=5.000
# Global-like model test accuracy: 0.0840, loss: 3.0865
# Client 0: test_acc=0.9121, test_loss=0.2740
# Client 1: test_acc=0.9173, test_loss=0.2551
# Client 2: test_acc=0.7165, test_loss=0.8966
# Client 3: test_acc=0.9585, test_loss=0.1298
# Client 4: test_acc=0.2176, test_loss=3.1423
# Client 5: test_acc=0.7693, test_loss=0.5747
# Client 6: test_acc=0.9230, test_loss=0.2495
# Client 7: test_acc=0.8982, test_loss=0.3327
# Client 8: test_acc=0.9826, test_loss=0.0540
# Client 9: test_acc=0.9806, test_loss=0.0620
# Average client test accuracy: 0.8276, Average client test loss: 0.5971
# Client 0: reward=1.4074 (local_acc=0.9962, cap=0.50, shared_dist=0.0888, epoch_req=0.100, comp_penalty=0.0000, shared_layers=3, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=0.3819 (local_acc=0.9562, cap=0.01, shared_dist=0.0942, epoch_req=0.500, comp_penalty=0.4900, shared_layers=4, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-4.2277 (local_acc=0.8665, cap=1.00, shared_dist=0.0942, epoch_req=0.500, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 3: reward=-11.2935 (local_acc=0.9899, cap=2.00, shared_dist=6.2834, epoch_req=0.500, comp_penalty=0.0000, shared_layers=6, pref_layers=2, exceed_layers=4, comm_penalty=8.0000)
# Client 4: reward=2.4968 (local_acc=0.6192, cap=2.00, shared_dist=0.1224, epoch_req=0.010, comp_penalty=0.0000, shared_layers=2, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=1.3390 (local_acc=0.9614, cap=0.50, shared_dist=0.1224, epoch_req=0.010, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-14.2928 (local_acc=0.9907, cap=1.00, shared_dist=6.2834, epoch_req=0.010, comp_penalty=0.0000, shared_layers=6, pref_layers=1, exceed_layers=5, comm_penalty=10.0000)
# Client 7: reward=2.8475 (local_acc=0.9876, cap=2.00, shared_dist=0.1401, epoch_req=2.000, comp_penalty=0.0000, shared_layers=5, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-3.9243 (local_acc=0.9981, cap=0.10, shared_dist=0.1224, epoch_req=5.000, comp_penalty=4.9000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.8596 (local_acc=0.9997, cap=5.00, shared_dist=0.1401, epoch_req=5.000, comp_penalty=0.0000, shared_layers=5, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 2.8725
#
# ===== Round 4 =====
# Client 0: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.0107, acc=0.9978, used=13834, eff_epochs=2.000
# Client 1: epoch_action=0.5, layer_action_value=5 -> shared_params=5, loss=0.0903, acc=0.9736, used=3732, eff_epochs=0.500
# Client 2: epoch_action=2.0, layer_action_value=1 -> shared_params=1, loss=0.0578, acc=0.9831, used=13338, eff_epochs=2.000
# Client 3: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.0375, acc=0.9895, used=2432, eff_epochs=0.500
# Client 4: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0587, acc=0.9843, used=12894, eff_epochs=2.000
# Client 5: epoch_action=5.0, layer_action_value=6 -> shared_params=6, loss=0.0175, acc=0.9965, used=14120, eff_epochs=5.000
# Client 6: epoch_action=0.1, layer_action_value=4 -> shared_params=4, loss=0.0137, acc=0.9979, used=567, eff_epochs=0.100
# Client 7: epoch_action=0.01, layer_action_value=5 -> shared_params=5, loss=0.0390, acc=0.9895, used=68, eff_epochs=0.010
# Client 8: epoch_action=5.0, layer_action_value=5 -> shared_params=5, loss=0.0039, acc=0.9996, used=25970, eff_epochs=5.000
# Client 9: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0041, acc=0.9989, used=35780, eff_epochs=5.000
# Global-like model test accuracy: 0.0843, loss: 3.0875
# Client 0: test_acc=0.9406, test_loss=0.1877
# Client 1: test_acc=0.9295, test_loss=0.1984
# Client 2: test_acc=0.9632, test_loss=0.1139
# Client 3: test_acc=0.9474, test_loss=0.1672
# Client 4: test_acc=0.8374, test_loss=0.4612
# Client 5: test_acc=0.9623, test_loss=0.1352
# Client 6: test_acc=0.9310, test_loss=0.2087
# Client 7: test_acc=0.9048, test_loss=0.3046
# Client 8: test_acc=0.9847, test_loss=0.0497
# Client 9: test_acc=0.9827, test_loss=0.0557
# Average client test accuracy: 0.9384, Average client test loss: 0.1882
# Client 0: reward=-4.1609 (local_acc=0.9978, cap=0.50, shared_dist=0.1587, epoch_req=2.000, comp_penalty=1.5000, shared_layers=5, pref_layers=3, exceed_layers=2, comm_penalty=4.0000)
# Client 1: reward=0.3349 (local_acc=0.9736, cap=0.01, shared_dist=0.1587, epoch_req=0.500, comp_penalty=0.4900, shared_layers=5, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=0.7758 (local_acc=0.9831, cap=1.00, shared_dist=0.2072, epoch_req=2.000, comp_penalty=1.0000, shared_layers=1, pref_layers=1, exceed_layers=0, comm_penalty=0.0000)
# Client 3: reward=-1.1308 (local_acc=0.9895, cap=2.00, shared_dist=0.1203, epoch_req=0.500, comp_penalty=0.0000, shared_layers=4, pref_layers=2, exceed_layers=2, comm_penalty=4.0000)
# Client 4: reward=2.8752 (local_acc=0.9843, cap=2.00, shared_dist=0.1092, epoch_req=2.000, comp_penalty=0.0000, shared_layers=3, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=-3.1358 (local_acc=0.9965, cap=0.50, shared_dist=0.1322, epoch_req=5.000, comp_penalty=4.5000, shared_layers=6, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-4.1224 (local_acc=0.9979, cap=1.00, shared_dist=0.1203, epoch_req=0.100, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 7: reward=2.8309 (local_acc=0.9895, cap=2.00, shared_dist=0.1587, epoch_req=0.010, comp_penalty=0.0000, shared_layers=5, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-9.9591 (local_acc=0.9996, cap=0.10, shared_dist=0.1587, epoch_req=5.000, comp_penalty=4.9000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 9: reward=5.8482 (local_acc=0.9989, cap=5.00, shared_dist=0.1507, epoch_req=5.000, comp_penalty=0.0000, shared_layers=2, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 1.9370
#
# ===== Round 5 =====
# Client 0: epoch_action=0.1, layer_action_value=5 -> shared_params=5, loss=0.0137, acc=0.9965, used=692, eff_epochs=0.100
# Client 1: epoch_action=2.0, layer_action_value=6 -> shared_params=6, loss=0.0406, acc=0.9878, used=14926, eff_epochs=2.000
# Client 2: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0210, acc=0.9952, used=13338, eff_epochs=2.000
# Client 3: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0200, acc=0.9955, used=486, eff_epochs=0.100
# Client 4: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0681, acc=0.9817, used=645, eff_epochs=0.100
# Client 5: epoch_action=0.01, layer_action_value=6 -> shared_params=6, loss=0.0155, acc=0.9979, used=28, eff_epochs=0.010
# Client 6: epoch_action=0.01, layer_action_value=3 -> shared_params=3, loss=0.0157, acc=0.9974, used=57, eff_epochs=0.010
# Client 7: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0195, acc=0.9950, used=3396, eff_epochs=0.500
# Client 8: epoch_action=0.5, layer_action_value=5 -> shared_params=5, loss=0.0031, acc=0.9992, used=2597, eff_epochs=0.500
# Client 9: epoch_action=2.0, layer_action_value=2 -> shared_params=2, loss=0.0023, acc=0.9993, used=14312, eff_epochs=2.000
# Global-like model test accuracy: 0.0840, loss: 3.0874
# Client 0: test_acc=0.9326, test_loss=0.2115
# Client 1: test_acc=0.9711, test_loss=0.0968
# Client 2: test_acc=0.9713, test_loss=0.0862
# Client 3: test_acc=0.9605, test_loss=0.1171
# Client 4: test_acc=0.8340, test_loss=0.4919
# Client 5: test_acc=0.9614, test_loss=0.1396
# Client 6: test_acc=0.9312, test_loss=0.2108
# Client 7: test_acc=0.9039, test_loss=0.2879
# Client 8: test_acc=0.9853, test_loss=0.0443
# Client 9: test_acc=0.9841, test_loss=0.0491
# Average client test accuracy: 0.9435, Average client test loss: 0.1735
# Client 0: reward=-2.5832 (local_acc=0.9965, cap=0.50, shared_dist=0.0797, epoch_req=0.100, comp_penalty=0.0000, shared_layers=5, pref_layers=3, exceed_layers=2, comm_penalty=4.0000)
# Client 1: reward=-41.7253 (local_acc=0.9878, cap=0.01, shared_dist=38.7331, epoch_req=2.000, comp_penalty=1.9900, shared_layers=6, pref_layers=5, exceed_layers=1, comm_penalty=2.0000)
# Client 2: reward=-3.0555 (local_acc=0.9952, cap=1.00, shared_dist=0.0507, epoch_req=2.000, comp_penalty=1.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 3: reward=2.9261 (local_acc=0.9955, cap=2.00, shared_dist=0.0694, epoch_req=0.100, comp_penalty=0.0000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9123 (local_acc=0.9817, cap=2.00, shared_dist=0.0694, epoch_req=0.100, comp_penalty=0.0000, shared_layers=2, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=-37.2352 (local_acc=0.9979, cap=0.50, shared_dist=38.7331, epoch_req=0.010, comp_penalty=0.0000, shared_layers=6, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-2.0533 (local_acc=0.9974, cap=1.00, shared_dist=0.0507, epoch_req=0.010, comp_penalty=0.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 7: reward=2.9443 (local_acc=0.9950, cap=2.00, shared_dist=0.0507, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-5.3805 (local_acc=0.9992, cap=0.10, shared_dist=0.0797, epoch_req=0.500, comp_penalty=0.4000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 9: reward=5.9299 (local_acc=0.9993, cap=5.00, shared_dist=0.0694, epoch_req=2.000, comp_penalty=0.0000, shared_layers=2, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 6.0475
#
# ===== Round 6 =====
# Client 0: epoch_action=0.5, layer_action_value=5 -> shared_params=5, loss=0.0090, acc=0.9981, used=3458, eff_epochs=0.500
# Client 1: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0397, acc=0.9890, used=746, eff_epochs=0.100
# Client 2: epoch_action=0.01, layer_action_value=3 -> shared_params=3, loss=0.0155, acc=0.9967, used=67, eff_epochs=0.010
# Client 3: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0077, acc=0.9981, used=24320, eff_epochs=5.000
# Client 4: epoch_action=0.5, layer_action_value=6 -> shared_params=6, loss=0.1301, acc=0.9601, used=3224, eff_epochs=0.500
# Client 5: epoch_action=0.1, layer_action_value=1 -> shared_params=1, loss=0.0151, acc=0.9975, used=282, eff_epochs=0.100
# Client 6: epoch_action=1.0, layer_action_value=4 -> shared_params=4, loss=0.0047, acc=0.9986, used=5674, eff_epochs=1.000
# Client 7: epoch_action=0.1, layer_action_value=1 -> shared_params=1, loss=0.0137, acc=0.9966, used=679, eff_epochs=0.100
# Client 8: epoch_action=0.5, layer_action_value=2 -> shared_params=2, loss=0.0025, acc=0.9996, used=2597, eff_epochs=0.500
# Client 9: epoch_action=2.0, layer_action_value=4 -> shared_params=4, loss=0.0013, acc=0.9997, used=14312, eff_epochs=2.000
# Global-like model test accuracy: 0.0836, loss: 3.1543
# Client 0: test_acc=0.9336, test_loss=0.2016
# Client 1: test_acc=0.9689, test_loss=0.0926
# Client 2: test_acc=0.9731, test_loss=0.0803
# Client 3: test_acc=0.9705, test_loss=0.0911
# Client 4: test_acc=0.7878, test_loss=0.6873
# Client 5: test_acc=0.9615, test_loss=0.1349
# Client 6: test_acc=0.9437, test_loss=0.1684
# Client 7: test_acc=0.9077, test_loss=0.2826
# Client 8: test_acc=0.9850, test_loss=0.0431
# Client 9: test_acc=0.9843, test_loss=0.0502
# Average client test accuracy: 0.9416, Average client test loss: 0.1832
# Client 0: reward=-2.6226 (local_acc=0.9981, cap=0.50, shared_dist=0.1208, epoch_req=0.500, comp_penalty=0.0000, shared_layers=5, pref_layers=3, exceed_layers=2, comm_penalty=4.0000)
# Client 1: reward=0.8613 (local_acc=0.9890, cap=0.01, shared_dist=0.0477, epoch_req=0.100, comp_penalty=0.0900, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-2.0510 (local_acc=0.9967, cap=1.00, shared_dist=0.0477, epoch_req=0.010, comp_penalty=0.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 3: reward=-0.0699 (local_acc=0.9981, cap=2.00, shared_dist=0.0680, epoch_req=5.000, comp_penalty=3.0000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=-1.1405 (local_acc=0.9601, cap=2.00, shared_dist=0.1006, epoch_req=0.500, comp_penalty=0.0000, shared_layers=6, pref_layers=4, exceed_layers=2, comm_penalty=4.0000)
# Client 5: reward=1.4166 (local_acc=0.9975, cap=0.50, shared_dist=0.0809, epoch_req=0.100, comp_penalty=0.0000, shared_layers=1, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-4.0979 (local_acc=0.9986, cap=1.00, shared_dist=0.0965, epoch_req=1.000, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 7: reward=2.9157 (local_acc=0.9966, cap=2.00, shared_dist=0.0809, epoch_req=0.100, comp_penalty=0.0000, shared_layers=1, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=0.6316 (local_acc=0.9996, cap=0.10, shared_dist=0.0680, epoch_req=0.500, comp_penalty=0.4000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.9032 (local_acc=0.9997, cap=5.00, shared_dist=0.0965, epoch_req=2.000, comp_penalty=0.0000, shared_layers=4, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 0.9307
#
# ===== Round 7 =====
# Client 0: epoch_action=0.1, layer_action_value=6 -> shared_params=6, loss=0.0059, acc=0.9984, used=692, eff_epochs=0.100
# Client 1: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0509, acc=0.9843, used=746, eff_epochs=0.100
# Client 2: epoch_action=0.1, layer_action_value=4 -> shared_params=4, loss=0.0325, acc=0.9897, used=667, eff_epochs=0.100
# Client 3: epoch_action=1.0, layer_action_value=2 -> shared_params=2, loss=0.0183, acc=0.9957, used=4864, eff_epochs=1.000
# Client 4: epoch_action=0.5, layer_action_value=2 -> shared_params=2, loss=0.0541, acc=0.9845, used=3224, eff_epochs=0.500
# Client 5: epoch_action=1.0, layer_action_value=3 -> shared_params=3, loss=0.0069, acc=0.9996, used=2824, eff_epochs=1.000
# Client 6: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0033, acc=0.9995, used=11348, eff_epochs=2.000
# Client 7: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0121, acc=0.9968, used=679, eff_epochs=0.100
# Client 8: epoch_action=1.0, layer_action_value=1 -> shared_params=1, loss=0.0015, acc=0.9998, used=5194, eff_epochs=1.000
# Client 9: epoch_action=1.0, layer_action_value=2 -> shared_params=2, loss=0.0009, acc=1.0000, used=7156, eff_epochs=1.000
# Global-like model test accuracy: 0.0837, loss: 3.1409
# Client 0: test_acc=0.9365, test_loss=0.1915
# Client 1: test_acc=0.9649, test_loss=0.1075
# Client 2: test_acc=0.9627, test_loss=0.1115
# Client 3: test_acc=0.9551, test_loss=0.1391
# Client 4: test_acc=0.8594, test_loss=0.4270
# Client 5: test_acc=0.9661, test_loss=0.1212
# Client 6: test_acc=0.9531, test_loss=0.1382
# Client 7: test_acc=0.9029, test_loss=0.2955
# Client 8: test_acc=0.9839, test_loss=0.0465
# Client 9: test_acc=0.9849, test_loss=0.0475
# Average client test accuracy: 0.9469, Average client test loss: 0.1625
# Client 0: reward=-4.5375 (local_acc=0.9984, cap=0.50, shared_dist=0.0359, epoch_req=0.100, comp_penalty=0.0000, shared_layers=6, pref_layers=3, exceed_layers=3, comm_penalty=6.0000)
# Client 1: reward=0.8560 (local_acc=0.9843, cap=0.01, shared_dist=0.0483, epoch_req=0.100, comp_penalty=0.0900, shared_layers=2, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-4.0642 (local_acc=0.9897, cap=1.00, shared_dist=0.0539, epoch_req=0.100, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 3: reward=2.9474 (local_acc=0.9957, cap=2.00, shared_dist=0.0483, epoch_req=1.000, comp_penalty=0.0000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9362 (local_acc=0.9845, cap=2.00, shared_dist=0.0483, epoch_req=0.500, comp_penalty=0.0000, shared_layers=2, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=0.9655 (local_acc=0.9996, cap=0.50, shared_dist=0.0342, epoch_req=1.000, comp_penalty=0.5000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-3.0347 (local_acc=0.9995, cap=1.00, shared_dist=0.0342, epoch_req=2.000, comp_penalty=1.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 7: reward=2.9485 (local_acc=0.9968, cap=2.00, shared_dist=0.0483, epoch_req=0.100, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=0.1306 (local_acc=0.9998, cap=0.10, shared_dist=0.0692, epoch_req=1.000, comp_penalty=0.9000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.9517 (local_acc=1.0000, cap=5.00, shared_dist=0.0483, epoch_req=1.000, comp_penalty=0.0000, shared_layers=2, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 1.3379
#
# ===== Round 8 =====
# Client 0: epoch_action=2.0, layer_action_value=2 -> shared_params=2, loss=0.0116, acc=0.9970, used=13834, eff_epochs=2.000
# Client 1: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.0182, acc=0.9957, used=14926, eff_epochs=2.000
# Client 2: epoch_action=0.01, layer_action_value=4 -> shared_params=4, loss=0.0269, acc=0.9921, used=67, eff_epochs=0.010
# Client 3: epoch_action=0.1, layer_action_value=5 -> shared_params=5, loss=0.0086, acc=0.9981, used=486, eff_epochs=0.100
# Client 4: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.0291, acc=0.9930, used=3224, eff_epochs=0.500
# Client 5: epoch_action=1.0, layer_action_value=5 -> shared_params=5, loss=0.0052, acc=0.9996, used=2824, eff_epochs=1.000
# Client 6: epoch_action=0.5, layer_action_value=6 -> shared_params=6, loss=0.0041, acc=0.9991, used=2837, eff_epochs=0.500
# Client 7: epoch_action=1.0, layer_action_value=4 -> shared_params=4, loss=0.0103, acc=0.9973, used=6792, eff_epochs=1.000
# Client 8: epoch_action=2.0, layer_action_value=6 -> shared_params=6, loss=0.0021, acc=1.0000, used=10388, eff_epochs=2.000
# Client 9: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0006, acc=1.0000, used=35780, eff_epochs=5.000
# Global-like model test accuracy: 0.0843, loss: 3.0617
# Client 0: test_acc=0.9308, test_loss=0.2192
# Client 1: test_acc=0.9818, test_loss=0.0552
# Client 2: test_acc=0.9647, test_loss=0.1046
# Client 3: test_acc=0.9698, test_loss=0.0919
# Client 4: test_acc=0.9246, test_loss=0.2340
# Client 5: test_acc=0.9619, test_loss=0.1339
# Client 6: test_acc=0.9394, test_loss=0.1775
# Client 7: test_acc=0.9539, test_loss=0.1403
# Client 8: test_acc=0.9846, test_loss=0.0515
# Client 9: test_acc=0.9847, test_loss=0.0533
# Average client test accuracy: 0.9596, Average client test loss: 0.1261
# Client 0: reward=-0.0854 (local_acc=0.9970, cap=0.50, shared_dist=0.0824, epoch_req=2.000, comp_penalty=1.5000, shared_layers=2, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=-1.1068 (local_acc=0.9957, cap=0.01, shared_dist=0.1225, epoch_req=2.000, comp_penalty=1.9900, shared_layers=5, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-4.0938 (local_acc=0.9921, cap=1.00, shared_dist=0.0858, epoch_req=0.010, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 3: reward=-3.1243 (local_acc=0.9981, cap=2.00, shared_dist=0.1225, epoch_req=0.100, comp_penalty=0.0000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 4: reward=2.9072 (local_acc=0.9930, cap=2.00, shared_dist=0.0858, epoch_req=0.500, comp_penalty=0.0000, shared_layers=4, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=0.8772 (local_acc=0.9996, cap=0.50, shared_dist=0.1225, epoch_req=1.000, comp_penalty=0.5000, shared_layers=5, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-27.7696 (local_acc=0.9991, cap=1.00, shared_dist=19.7687, epoch_req=0.500, comp_penalty=0.0000, shared_layers=6, pref_layers=1, exceed_layers=5, comm_penalty=10.0000)
# Client 7: reward=2.9115 (local_acc=0.9973, cap=2.00, shared_dist=0.0858, epoch_req=1.000, comp_penalty=0.0000, shared_layers=4, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-28.5687 (local_acc=1.0000, cap=0.10, shared_dist=19.7687, epoch_req=2.000, comp_penalty=1.9000, shared_layers=6, pref_layers=2, exceed_layers=4, comm_penalty=8.0000)
# Client 9: reward=5.9176 (local_acc=1.0000, cap=5.00, shared_dist=0.0824, epoch_req=5.000, comp_penalty=0.0000, shared_layers=2, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 3.9225
#
# ===== Round 9 =====
# Client 0: epoch_action=5.0, layer_action_value=3 -> shared_params=3, loss=0.0069, acc=0.9983, used=34585, eff_epochs=5.000
# Client 1: epoch_action=5.0, layer_action_value=1 -> shared_params=1, loss=0.0049, acc=0.9988, used=37315, eff_epochs=5.000
# Client 2: epoch_action=0.1, layer_action_value=5 -> shared_params=5, loss=0.0141, acc=0.9957, used=667, eff_epochs=0.100
# Client 3: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0140, acc=0.9957, used=2432, eff_epochs=0.500
# Client 4: epoch_action=1.0, layer_action_value=5 -> shared_params=5, loss=0.0160, acc=0.9964, used=6447, eff_epochs=1.000
# Client 5: epoch_action=5.0, layer_action_value=5 -> shared_params=5, loss=0.0019, acc=0.9996, used=14120, eff_epochs=5.000
# Client 6: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0071, acc=0.9981, used=567, eff_epochs=0.100
# Client 7: epoch_action=5.0, layer_action_value=3 -> shared_params=3, loss=0.0041, acc=0.9990, used=33960, eff_epochs=5.000
# Client 8: epoch_action=1.0, layer_action_value=6 -> shared_params=6, loss=0.0028, acc=0.9996, used=5194, eff_epochs=1.000
# Client 9: epoch_action=2.0, layer_action_value=1 -> shared_params=1, loss=0.0010, acc=0.9999, used=14312, eff_epochs=2.000
# Global-like model test accuracy: 0.0836, loss: 3.0549
# Client 0: test_acc=0.9497, test_loss=0.1677
# Client 1: test_acc=0.9838, test_loss=0.0509
# Client 2: test_acc=0.9782, test_loss=0.0692
# Client 3: test_acc=0.9515, test_loss=0.1439
# Client 4: test_acc=0.9273, test_loss=0.2287
# Client 5: test_acc=0.9691, test_loss=0.1013
# Client 6: test_acc=0.9459, test_loss=0.1601
# Client 7: test_acc=0.9474, test_loss=0.1705
# Client 8: test_acc=0.9831, test_loss=0.0592
# Client 9: test_acc=0.9845, test_loss=0.0475
# Average client test accuracy: 0.9620, Average client test loss: 0.1199
# Client 0: reward=-3.0821 (local_acc=0.9983, cap=0.50, shared_dist=0.0804, epoch_req=5.000, comp_penalty=4.5000, shared_layers=3, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=-4.1088 (local_acc=0.9988, cap=0.01, shared_dist=0.1276, epoch_req=5.000, comp_penalty=4.9900, shared_layers=1, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-6.1842 (local_acc=0.9957, cap=1.00, shared_dist=0.1799, epoch_req=0.100, comp_penalty=0.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 3: reward=2.8681 (local_acc=0.9957, cap=2.00, shared_dist=0.1276, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=0.8166 (local_acc=0.9964, cap=2.00, shared_dist=0.1799, epoch_req=1.000, comp_penalty=0.0000, shared_layers=5, pref_layers=4, exceed_layers=1, comm_penalty=2.0000)
# Client 5: reward=-3.1802 (local_acc=0.9996, cap=0.50, shared_dist=0.1799, epoch_req=5.000, comp_penalty=4.5000, shared_layers=5, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-2.0824 (local_acc=0.9981, cap=1.00, shared_dist=0.0804, epoch_req=0.100, comp_penalty=0.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 7: reward=-0.0814 (local_acc=0.9990, cap=2.00, shared_dist=0.0804, epoch_req=5.000, comp_penalty=3.0000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-7.9503 (local_acc=0.9996, cap=0.10, shared_dist=0.1499, epoch_req=1.000, comp_penalty=0.9000, shared_layers=6, pref_layers=2, exceed_layers=4, comm_penalty=8.0000)
# Client 9: reward=5.8723 (local_acc=0.9999, cap=5.00, shared_dist=0.1276, epoch_req=2.000, comp_penalty=0.0000, shared_layers=1, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 1.5219
#
# ===== Round 10 =====
# Client 0: epoch_action=5.0, layer_action_value=6 -> shared_params=6, loss=0.0025, acc=0.9996, used=34585, eff_epochs=5.000
# Client 1: epoch_action=1.0, layer_action_value=6 -> shared_params=6, loss=0.0053, acc=0.9991, used=7463, eff_epochs=1.000
# Client 2: epoch_action=1.0, layer_action_value=6 -> shared_params=6, loss=0.0197, acc=0.9949, used=6669, eff_epochs=1.000
# Client 3: epoch_action=0.1, layer_action_value=4 -> shared_params=4, loss=0.0063, acc=0.9988, used=486, eff_epochs=0.100
# Client 4: epoch_action=1.0, layer_action_value=5 -> shared_params=5, loss=0.0225, acc=0.9940, used=6447, eff_epochs=1.000
# Client 5: epoch_action=0.1, layer_action_value=6 -> shared_params=6, loss=0.0019, acc=1.0000, used=282, eff_epochs=0.100
# Client 6: epoch_action=0.01, layer_action_value=5 -> shared_params=5, loss=0.0058, acc=0.9988, used=57, eff_epochs=0.010
# Client 7: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0025, acc=0.9997, used=13584, eff_epochs=2.000
# Client 8: epoch_action=0.5, layer_action_value=2 -> shared_params=2, loss=0.0014, acc=0.9996, used=2597, eff_epochs=0.500
# Client 9: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0007, acc=1.0000, used=3578, eff_epochs=0.500
# Global-like model test accuracy: 0.0834, loss: 3.0710
# Client 0: test_acc=0.9530, test_loss=0.1532
# Client 1: test_acc=0.9822, test_loss=0.0569
# Client 2: test_acc=0.9762, test_loss=0.0709
# Client 3: test_acc=0.9616, test_loss=0.1127
# Client 4: test_acc=0.9114, test_loss=0.2659
# Client 5: test_acc=0.9670, test_loss=0.1099
# Client 6: test_acc=0.9448, test_loss=0.1634
# Client 7: test_acc=0.9585, test_loss=0.1249
# Client 8: test_acc=0.9856, test_loss=0.0460
# Client 9: test_acc=0.9852, test_loss=0.0463
# Average client test accuracy: 0.9626, Average client test loss: 0.1150
# Client 0: reward=-54.0966 (local_acc=0.9996, cap=0.50, shared_dist=45.0961, epoch_req=5.000, comp_penalty=4.5000, shared_layers=6, pref_layers=3, exceed_layers=3, comm_penalty=6.0000)
# Client 1: reward=-47.0771 (local_acc=0.9991, cap=0.01, shared_dist=45.0961, epoch_req=1.000, comp_penalty=0.9900, shared_layers=6, pref_layers=5, exceed_layers=1, comm_penalty=2.0000)
# Client 2: reward=-53.1012 (local_acc=0.9949, cap=1.00, shared_dist=45.0961, epoch_req=1.000, comp_penalty=0.0000, shared_layers=6, pref_layers=1, exceed_layers=5, comm_penalty=10.0000)
# Client 3: reward=-1.0738 (local_acc=0.9988, cap=2.00, shared_dist=0.0726, epoch_req=0.100, comp_penalty=0.0000, shared_layers=4, pref_layers=2, exceed_layers=2, comm_penalty=4.0000)
# Client 4: reward=0.8786 (local_acc=0.9940, cap=2.00, shared_dist=0.1154, epoch_req=1.000, comp_penalty=0.0000, shared_layers=5, pref_layers=4, exceed_layers=1, comm_penalty=2.0000)
# Client 5: reward=-43.5961 (local_acc=1.0000, cap=0.50, shared_dist=45.0961, epoch_req=0.100, comp_penalty=0.0000, shared_layers=6, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-6.1166 (local_acc=0.9988, cap=1.00, shared_dist=0.1154, epoch_req=0.010, comp_penalty=0.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 7: reward=2.9456 (local_acc=0.9997, cap=2.00, shared_dist=0.0541, epoch_req=2.000, comp_penalty=0.0000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=0.6227 (local_acc=0.9996, cap=0.10, shared_dist=0.0769, epoch_req=0.500, comp_penalty=0.4000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.9459 (local_acc=1.0000, cap=5.00, shared_dist=0.0541, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 10.1353
#
# ===== Round 11 =====
# Client 0: epoch_action=1.0, layer_action_value=2 -> shared_params=2, loss=0.0008, acc=1.0000, used=6917, eff_epochs=1.000
# Client 1: epoch_action=2.0, layer_action_value=6 -> shared_params=6, loss=0.0031, acc=0.9993, used=14926, eff_epochs=2.000
# Client 2: epoch_action=0.01, layer_action_value=5 -> shared_params=5, loss=0.0161, acc=0.9958, used=67, eff_epochs=0.010
# Client 3: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0039, acc=0.9998, used=486, eff_epochs=0.100
# Client 4: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0151, acc=0.9952, used=645, eff_epochs=0.100
# Client 5: epoch_action=1.0, layer_action_value=2 -> shared_params=2, loss=0.0018, acc=1.0000, used=2824, eff_epochs=1.000
# Client 6: epoch_action=0.5, layer_action_value=5 -> shared_params=5, loss=0.0044, acc=0.9991, used=2837, eff_epochs=0.500
# Client 7: epoch_action=0.01, layer_action_value=1 -> shared_params=1, loss=0.0025, acc=0.9999, used=68, eff_epochs=0.010
# Client 8: epoch_action=0.5, layer_action_value=5 -> shared_params=5, loss=0.0007, acc=1.0000, used=2597, eff_epochs=0.500
# Client 9: epoch_action=2.0, layer_action_value=1 -> shared_params=1, loss=0.0005, acc=1.0000, used=14312, eff_epochs=2.000
# Global-like model test accuracy: 0.0839, loss: 3.0478
# Client 0: test_acc=0.9525, test_loss=0.1545
# Client 1: test_acc=0.9837, test_loss=0.0502
# Client 2: test_acc=0.9770, test_loss=0.0697
# Client 3: test_acc=0.9663, test_loss=0.1020
# Client 4: test_acc=0.9401, test_loss=0.1943
# Client 5: test_acc=0.9691, test_loss=0.1024
# Client 6: test_acc=0.9429, test_loss=0.1724
# Client 7: test_acc=0.9578, test_loss=0.1256
# Client 8: test_acc=0.9868, test_loss=0.0430
# Client 9: test_acc=0.9865, test_loss=0.0425
# Average client test accuracy: 0.9663, Average client test loss: 0.1057
# Client 0: reward=0.9641 (local_acc=1.0000, cap=0.50, shared_dist=0.0359, epoch_req=1.000, comp_penalty=0.5000, shared_layers=2, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=-3.0255 (local_acc=0.9993, cap=0.01, shared_dist=0.0448, epoch_req=2.000, comp_penalty=1.9900, shared_layers=6, pref_layers=5, exceed_layers=1, comm_penalty=2.0000)
# Client 2: reward=-6.0580 (local_acc=0.9958, cap=1.00, shared_dist=0.0538, epoch_req=0.010, comp_penalty=0.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 3: reward=2.9639 (local_acc=0.9998, cap=2.00, shared_dist=0.0359, epoch_req=0.100, comp_penalty=0.0000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9593 (local_acc=0.9952, cap=2.00, shared_dist=0.0359, epoch_req=0.100, comp_penalty=0.0000, shared_layers=2, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=0.9641 (local_acc=1.0000, cap=0.50, shared_dist=0.0359, epoch_req=1.000, comp_penalty=0.5000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-6.0546 (local_acc=0.9991, cap=1.00, shared_dist=0.0538, epoch_req=0.500, comp_penalty=0.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 7: reward=2.9577 (local_acc=0.9999, cap=2.00, shared_dist=0.0422, epoch_req=0.010, comp_penalty=0.0000, shared_layers=1, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-5.3538 (local_acc=1.0000, cap=0.10, shared_dist=0.0538, epoch_req=0.500, comp_penalty=0.4000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 9: reward=5.9578 (local_acc=1.0000, cap=5.00, shared_dist=0.0422, epoch_req=2.000, comp_penalty=0.0000, shared_layers=1, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 1.4397
#
# ===== Round 12 =====
# Client 0: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0017, acc=0.9996, used=34585, eff_epochs=5.000
# Client 1: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.0043, acc=0.9988, used=14926, eff_epochs=2.000
# Client 2: epoch_action=1.0, layer_action_value=5 -> shared_params=5, loss=0.0277, acc=0.9921, used=6669, eff_epochs=1.000
# Client 3: epoch_action=1.0, layer_action_value=1 -> shared_params=1, loss=0.0059, acc=0.9986, used=4864, eff_epochs=1.000
# Client 4: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0128, acc=0.9974, used=3224, eff_epochs=0.500
# Client 5: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.0019, acc=1.0000, used=5648, eff_epochs=2.000
# Client 6: epoch_action=0.01, layer_action_value=6 -> shared_params=6, loss=0.0037, acc=0.9991, used=57, eff_epochs=0.010
# Client 7: epoch_action=5.0, layer_action_value=2 -> shared_params=2, loss=0.0029, acc=0.9994, used=33960, eff_epochs=5.000
# Client 8: epoch_action=1.0, layer_action_value=5 -> shared_params=5, loss=0.0007, acc=1.0000, used=5194, eff_epochs=1.000
# Client 9: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0005, acc=1.0000, used=3578, eff_epochs=0.500
# Global-like model test accuracy: 0.0842, loss: 3.0131
# Client 0: test_acc=0.9588, test_loss=0.1312
# Client 1: test_acc=0.9815, test_loss=0.0601
# Client 2: test_acc=0.9478, test_loss=0.1582
# Client 3: test_acc=0.9720, test_loss=0.0899
# Client 4: test_acc=0.9424, test_loss=0.1859
# Client 5: test_acc=0.9679, test_loss=0.1082
# Client 6: test_acc=0.9431, test_loss=0.1733
# Client 7: test_acc=0.9556, test_loss=0.1450
# Client 8: test_acc=0.9877, test_loss=0.0400
# Client 9: test_acc=0.9862, test_loss=0.0447
# Average client test accuracy: 0.9643, Average client test loss: 0.1136
# Client 0: reward=-3.0926 (local_acc=0.9996, cap=0.50, shared_dist=0.0921, epoch_req=5.000, comp_penalty=4.5000, shared_layers=2, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=-1.0791 (local_acc=0.9988, cap=0.01, shared_dist=0.0979, epoch_req=2.000, comp_penalty=1.9900, shared_layers=5, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-6.1059 (local_acc=0.9921, cap=1.00, shared_dist=0.0979, epoch_req=1.000, comp_penalty=0.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 3: reward=2.9100 (local_acc=0.9986, cap=2.00, shared_dist=0.0886, epoch_req=1.000, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9088 (local_acc=0.9974, cap=2.00, shared_dist=0.0886, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=-0.0979 (local_acc=1.0000, cap=0.50, shared_dist=0.0979, epoch_req=2.000, comp_penalty=1.5000, shared_layers=5, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-8.0825 (local_acc=0.9991, cap=1.00, shared_dist=0.0816, epoch_req=0.010, comp_penalty=0.0000, shared_layers=6, pref_layers=1, exceed_layers=5, comm_penalty=10.0000)
# Client 7: reward=-0.0927 (local_acc=0.9994, cap=2.00, shared_dist=0.0921, epoch_req=5.000, comp_penalty=3.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-5.8979 (local_acc=1.0000, cap=0.10, shared_dist=0.0979, epoch_req=1.000, comp_penalty=0.9000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 9: reward=5.9114 (local_acc=1.0000, cap=5.00, shared_dist=0.0886, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 1.3184
#
# ===== Round 13 =====
# Client 0: epoch_action=1.0, layer_action_value=3 -> shared_params=3, loss=0.0005, acc=1.0000, used=6917, eff_epochs=1.000
# Client 1: epoch_action=2.0, layer_action_value=4 -> shared_params=4, loss=0.0034, acc=0.9991, used=14926, eff_epochs=2.000
# Client 2: epoch_action=1.0, layer_action_value=2 -> shared_params=2, loss=0.0061, acc=0.9985, used=6669, eff_epochs=1.000
# Client 3: epoch_action=0.01, layer_action_value=2 -> shared_params=2, loss=0.0060, acc=0.9990, used=49, eff_epochs=0.010
# Client 4: epoch_action=5.0, layer_action_value=4 -> shared_params=4, loss=0.0044, acc=0.9994, used=32235, eff_epochs=5.000
# Client 5: epoch_action=2.0, layer_action_value=4 -> shared_params=4, loss=0.0013, acc=1.0000, used=5648, eff_epochs=2.000
# Client 6: epoch_action=0.1, layer_action_value=2 -> shared_params=2, loss=0.0021, acc=1.0000, used=567, eff_epochs=0.100
# Client 7: epoch_action=5.0, layer_action_value=1 -> shared_params=1, loss=0.0008, acc=1.0000, used=33960, eff_epochs=5.000
# Client 8: epoch_action=0.01, layer_action_value=5 -> shared_params=5, loss=0.0007, acc=1.0000, used=52, eff_epochs=0.010
# Client 9: epoch_action=2.0, layer_action_value=6 -> shared_params=6, loss=0.0009, acc=1.0000, used=14312, eff_epochs=2.000
# Global-like model test accuracy: 0.0838, loss: 2.9971
# Client 0: test_acc=0.9611, test_loss=0.1276
# Client 1: test_acc=0.9849, test_loss=0.0492
# Client 2: test_acc=0.9775, test_loss=0.0718
# Client 3: test_acc=0.9704, test_loss=0.0931
# Client 4: test_acc=0.9544, test_loss=0.1460
# Client 5: test_acc=0.9696, test_loss=0.0943
# Client 6: test_acc=0.9472, test_loss=0.1618
# Client 7: test_acc=0.9587, test_loss=0.1276
# Client 8: test_acc=0.9876, test_loss=0.0416
# Client 9: test_acc=0.9836, test_loss=0.0518
# Average client test accuracy: 0.9695, Average client test loss: 0.0965
# Client 0: reward=0.9443 (local_acc=1.0000, cap=0.50, shared_dist=0.0557, epoch_req=1.000, comp_penalty=0.5000, shared_layers=3, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=-1.0729 (local_acc=0.9991, cap=0.01, shared_dist=0.0920, epoch_req=2.000, comp_penalty=1.9900, shared_layers=4, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-0.0801 (local_acc=0.9985, cap=1.00, shared_dist=0.0786, epoch_req=1.000, comp_penalty=0.0000, shared_layers=2, pref_layers=1, exceed_layers=1, comm_penalty=2.0000)
# Client 3: reward=2.9204 (local_acc=0.9990, cap=2.00, shared_dist=0.0786, epoch_req=0.010, comp_penalty=0.0000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=-0.0926 (local_acc=0.9994, cap=2.00, shared_dist=0.0920, epoch_req=5.000, comp_penalty=3.0000, shared_layers=4, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=-0.0920 (local_acc=1.0000, cap=0.50, shared_dist=0.0920, epoch_req=2.000, comp_penalty=1.5000, shared_layers=4, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-0.0786 (local_acc=1.0000, cap=1.00, shared_dist=0.0786, epoch_req=0.100, comp_penalty=0.0000, shared_layers=2, pref_layers=1, exceed_layers=1, comm_penalty=2.0000)
# Client 7: reward=-0.0921 (local_acc=1.0000, cap=2.00, shared_dist=0.0921, epoch_req=5.000, comp_penalty=3.0000, shared_layers=1, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-4.9821 (local_acc=1.0000, cap=0.10, shared_dist=0.0821, epoch_req=0.010, comp_penalty=0.0000, shared_layers=5, pref_layers=2, exceed_layers=3, comm_penalty=6.0000)
# Client 9: reward=3.9316 (local_acc=1.0000, cap=5.00, shared_dist=0.0684, epoch_req=2.000, comp_penalty=0.0000, shared_layers=6, pref_layers=5, exceed_layers=1, comm_penalty=2.0000)
# RL loss: 0.4847
#
# ===== Round 14 =====
# Client 0: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0003, acc=1.0000, used=13834, eff_epochs=2.000
# Client 1: epoch_action=0.01, layer_action_value=4 -> shared_params=4, loss=0.0025, acc=0.9992, used=75, eff_epochs=0.010
# Client 2: epoch_action=1.0, layer_action_value=3 -> shared_params=3, loss=0.0064, acc=0.9985, used=6669, eff_epochs=1.000
# Client 3: epoch_action=0.01, layer_action_value=4 -> shared_params=4, loss=0.0088, acc=0.9979, used=49, eff_epochs=0.010
# Client 4: epoch_action=1.0, layer_action_value=6 -> shared_params=6, loss=0.0035, acc=0.9988, used=6447, eff_epochs=1.000
# ...
# Client 3: reward=-4.0627 (local_acc=1.0000, cap=2.00, shared_dist=0.0627, epoch_req=5.000, comp_penalty=3.0000, shared_layers=4, pref_layers=2, exceed_layers=2, comm_penalty=4.0000)
# Client 4: reward=0.9187 (local_acc=1.0000, cap=2.00, shared_dist=0.0813, epoch_req=0.500, comp_penalty=0.0000, shared_layers=5, pref_layers=4, exceed_layers=1, comm_penalty=2.0000)
# Client 5: reward=1.4490 (local_acc=1.0000, cap=0.50, shared_dist=0.0510, epoch_req=0.500, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=1.9396 (local_acc=1.0000, cap=1.00, shared_dist=0.0604, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=1, exceed_layers=0, comm_penalty=0.0000)
# Client 7: reward=2.9490 (local_acc=1.0000, cap=2.00, shared_dist=0.0510, epoch_req=0.500, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=0.6396 (local_acc=1.0000, cap=0.10, shared_dist=0.0604, epoch_req=0.500, comp_penalty=0.4000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=-13.5773 (local_acc=0.9905, cap=5.00, shared_dist=17.5678, epoch_req=1.000, comp_penalty=0.0000, shared_layers=6, pref_layers=5, exceed_layers=1, comm_penalty=2.0000)
# RL loss: 0.7362
#
# ===== Round 97 =====
# Client 0: epoch_action=2.0, layer_action_value=6 -> shared_params=6, loss=0.0095, acc=0.9970, used=13834, eff_epochs=2.000
# Client 1: epoch_action=0.1, layer_action_value=5 -> shared_params=5, loss=0.0003, acc=1.0000, used=746, eff_epochs=0.100
# Client 2: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=3334, eff_epochs=0.500
# Client 3: epoch_action=1.0, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=4864, eff_epochs=1.000
# Client 4: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.0002, acc=1.0000, used=3224, eff_epochs=0.500
# Client 5: epoch_action=0.5, layer_action_value=2 -> shared_params=2, loss=0.0002, acc=1.0000, used=1412, eff_epochs=0.500
# Client 6: epoch_action=1.0, layer_action_value=1 -> shared_params=1, loss=0.0002, acc=1.0000, used=5674, eff_epochs=1.000
# Client 7: epoch_action=2.0, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=13584, eff_epochs=2.000
# Client 8: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0005, acc=1.0000, used=2597, eff_epochs=0.500
# Client 9: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0668, acc=0.9775, used=3578, eff_epochs=0.500
# Global-like model test accuracy: 0.0839, loss: 2.6546
# Client 0: test_acc=0.9633, test_loss=0.1232
# Client 1: test_acc=0.9886, test_loss=0.0381
# Client 2: test_acc=0.9849, test_loss=0.0472
# Client 3: test_acc=0.9816, test_loss=0.0574
# Client 4: test_acc=0.9622, test_loss=0.1198
# Client 5: test_acc=0.9729, test_loss=0.0856
# Client 6: test_acc=0.9612, test_loss=0.1257
# Client 7: test_acc=0.9659, test_loss=0.1064
# Client 8: test_acc=0.9869, test_loss=0.0432
# Client 9: test_acc=0.9566, test_loss=0.1461
# Average client test accuracy: 0.9724, Average client test loss: 0.0893
# Client 0: reward=-6.0513 (local_acc=0.9970, cap=0.50, shared_dist=0.0483, epoch_req=2.000, comp_penalty=1.5000, shared_layers=6, pref_layers=3, exceed_layers=3, comm_penalty=6.0000)
# Client 1: reward=0.8621 (local_acc=1.0000, cap=0.01, shared_dist=0.0579, epoch_req=0.100, comp_penalty=0.0900, shared_layers=5, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=1.9617 (local_acc=1.0000, cap=1.00, shared_dist=0.0383, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=1, exceed_layers=0, comm_penalty=0.0000)
# Client 3: reward=2.9617 (local_acc=1.0000, cap=2.00, shared_dist=0.0383, epoch_req=1.000, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9562 (local_acc=1.0000, cap=2.00, shared_dist=0.0438, epoch_req=0.500, comp_penalty=0.0000, shared_layers=4, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=1.4689 (local_acc=1.0000, cap=0.50, shared_dist=0.0311, epoch_req=0.500, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=1.9617 (local_acc=1.0000, cap=1.00, shared_dist=0.0383, epoch_req=1.000, comp_penalty=0.0000, shared_layers=1, pref_layers=1, exceed_layers=0, comm_penalty=0.0000)
# Client 7: reward=2.9617 (local_acc=1.0000, cap=2.00, shared_dist=0.0383, epoch_req=2.000, comp_penalty=0.0000, shared_layers=1, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=0.6617 (local_acc=1.0000, cap=0.10, shared_dist=0.0383, epoch_req=0.500, comp_penalty=0.4000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.9543 (local_acc=0.9775, cap=5.00, shared_dist=0.0232, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 0.1014
#
# ===== Round 98 =====
# Client 0: epoch_action=0.1, layer_action_value=5 -> shared_params=5, loss=0.0022, acc=0.9997, used=692, eff_epochs=0.100
# Client 1: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0002, acc=1.0000, used=746, eff_epochs=0.100
# Client 2: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0002, acc=1.0000, used=667, eff_epochs=0.100
# Client 3: epoch_action=1.0, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=4864, eff_epochs=1.000
# Client 4: epoch_action=0.1, layer_action_value=6 -> shared_params=6, loss=0.0002, acc=1.0000, used=645, eff_epochs=0.100
# Client 5: epoch_action=1.0, layer_action_value=5 -> shared_params=5, loss=0.0002, acc=1.0000, used=2824, eff_epochs=1.000
# Client 6: epoch_action=2.0, layer_action_value=5 -> shared_params=5, loss=0.0002, acc=1.0000, used=11348, eff_epochs=2.000
# Client 7: epoch_action=0.01, layer_action_value=4 -> shared_params=4, loss=0.0003, acc=1.0000, used=68, eff_epochs=0.010
# Client 8: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=2597, eff_epochs=0.500
# Client 9: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.0120, acc=0.9966, used=3578, eff_epochs=0.500
# Global-like model test accuracy: 0.0843, loss: 2.6410
# Client 0: test_acc=0.9742, test_loss=0.0838
# Client 1: test_acc=0.9889, test_loss=0.0380
# Client 2: test_acc=0.9855, test_loss=0.0452
# Client 3: test_acc=0.9808, test_loss=0.0594
# Client 4: test_acc=0.9619, test_loss=0.1199
# Client 5: test_acc=0.9732, test_loss=0.0859
# Client 6: test_acc=0.9597, test_loss=0.1238
# Client 7: test_acc=0.9670, test_loss=0.1035
# Client 8: test_acc=0.9885, test_loss=0.0375
# Client 9: test_acc=0.9742, test_loss=0.0821
# Average client test accuracy: 0.9754, Average client test loss: 0.0779
# Client 0: reward=-2.5644 (local_acc=0.9997, cap=0.50, shared_dist=0.0641, epoch_req=0.100, comp_penalty=0.0000, shared_layers=5, pref_layers=3, exceed_layers=2, comm_penalty=4.0000)
# Client 1: reward=0.9071 (local_acc=1.0000, cap=0.01, shared_dist=0.0129, epoch_req=0.100, comp_penalty=0.0900, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-2.0129 (local_acc=1.0000, cap=1.00, shared_dist=0.0129, epoch_req=0.100, comp_penalty=0.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 3: reward=2.9780 (local_acc=1.0000, cap=2.00, shared_dist=0.0220, epoch_req=1.000, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=-1.0535 (local_acc=1.0000, cap=2.00, shared_dist=0.0535, epoch_req=0.100, comp_penalty=0.0000, shared_layers=6, pref_layers=4, exceed_layers=2, comm_penalty=4.0000)
# Client 5: reward=0.9359 (local_acc=1.0000, cap=0.50, shared_dist=0.0641, epoch_req=1.000, comp_penalty=0.5000, shared_layers=5, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-7.0641 (local_acc=1.0000, cap=1.00, shared_dist=0.0641, epoch_req=2.000, comp_penalty=1.0000, shared_layers=5, pref_layers=1, exceed_layers=4, comm_penalty=8.0000)
# Client 7: reward=2.9558 (local_acc=1.0000, cap=2.00, shared_dist=0.0442, epoch_req=0.010, comp_penalty=0.0000, shared_layers=4, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=0.6780 (local_acc=1.0000, cap=0.10, shared_dist=0.0220, epoch_req=0.500, comp_penalty=0.4000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.9525 (local_acc=0.9966, cap=5.00, shared_dist=0.0442, epoch_req=0.500, comp_penalty=0.0000, shared_layers=4, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 0.1244
#
# ===== Round 99 =====
# Client 0: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0028, acc=0.9991, used=692, eff_epochs=0.100
# Client 1: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0003, acc=1.0000, used=3732, eff_epochs=0.500
# Client 2: epoch_action=0.5, layer_action_value=4 -> shared_params=4, loss=0.0002, acc=1.0000, used=3334, eff_epochs=0.500
# Client 3: epoch_action=1.0, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=4864, eff_epochs=1.000
# Client 4: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0002, acc=1.0000, used=3224, eff_epochs=0.500
# Client 5: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0002, acc=1.0000, used=1412, eff_epochs=0.500
# Client 6: epoch_action=0.5, layer_action_value=2 -> shared_params=2, loss=0.0002, acc=1.0000, used=2837, eff_epochs=0.500
# Client 7: epoch_action=0.5, layer_action_value=2 -> shared_params=2, loss=0.0003, acc=1.0000, used=3396, eff_epochs=0.500
# Client 8: epoch_action=2.0, layer_action_value=2 -> shared_params=2, loss=0.0003, acc=1.0000, used=10388, eff_epochs=2.000
# Client 9: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0121, acc=0.9978, used=3578, eff_epochs=0.500
# Global-like model test accuracy: 0.0843, loss: 2.6386
# Client 0: test_acc=0.9732, test_loss=0.0837
# Client 1: test_acc=0.9881, test_loss=0.0397
# Client 2: test_acc=0.9852, test_loss=0.0469
# Client 3: test_acc=0.9805, test_loss=0.0623
# Client 4: test_acc=0.9627, test_loss=0.1141
# Client 5: test_acc=0.9722, test_loss=0.0858
# Client 6: test_acc=0.9594, test_loss=0.1298
# Client 7: test_acc=0.9657, test_loss=0.1028
# Client 8: test_acc=0.9883, test_loss=0.0372
# Client 9: test_acc=0.9817, test_loss=0.0600
# Average client test accuracy: 0.9757, Average client test loss: 0.0762
# Client 0: reward=1.4867 (local_acc=0.9991, cap=0.50, shared_dist=0.0124, epoch_req=0.100, comp_penalty=0.0000, shared_layers=3, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=0.5076 (local_acc=1.0000, cap=0.01, shared_dist=0.0124, epoch_req=0.500, comp_penalty=0.4900, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-4.0093 (local_acc=1.0000, cap=1.00, shared_dist=0.0093, epoch_req=0.500, comp_penalty=0.0000, shared_layers=4, pref_layers=1, exceed_layers=3, comm_penalty=6.0000)
# Client 3: reward=2.9792 (local_acc=1.0000, cap=2.00, shared_dist=0.0208, epoch_req=1.000, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9792 (local_acc=1.0000, cap=2.00, shared_dist=0.0208, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=1.4876 (local_acc=1.0000, cap=0.50, shared_dist=0.0124, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-0.0167 (local_acc=1.0000, cap=1.00, shared_dist=0.0167, epoch_req=0.500, comp_penalty=0.0000, shared_layers=2, pref_layers=1, exceed_layers=1, comm_penalty=2.0000)
# Client 7: reward=2.9833 (local_acc=1.0000, cap=2.00, shared_dist=0.0167, epoch_req=0.500, comp_penalty=0.0000, shared_layers=2, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-0.8167 (local_acc=1.0000, cap=0.10, shared_dist=0.0167, epoch_req=2.000, comp_penalty=1.9000, shared_layers=2, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 9: reward=5.9853 (local_acc=0.9978, cap=5.00, shared_dist=0.0124, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 0.0768
#
# ===== Round 100 =====
# Client 0: epoch_action=5.0, layer_action_value=3 -> shared_params=3, loss=0.0004, acc=1.0000, used=34585, eff_epochs=5.000
# Client 1: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0003, acc=1.0000, used=3732, eff_epochs=0.500
# Client 2: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0003, acc=1.0000, used=667, eff_epochs=0.100
# Client 3: epoch_action=0.5, layer_action_value=1 -> shared_params=1, loss=0.0003, acc=1.0000, used=2432, eff_epochs=0.500
# Client 4: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0002, acc=1.0000, used=12894, eff_epochs=2.000
# Client 5: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0002, acc=1.0000, used=1412, eff_epochs=0.500
# Client 6: epoch_action=1.0, layer_action_value=3 -> shared_params=3, loss=0.0002, acc=1.0000, used=5674, eff_epochs=1.000
# Client 7: epoch_action=0.5, layer_action_value=3 -> shared_params=3, loss=0.0003, acc=1.0000, used=3396, eff_epochs=0.500
# Client 8: epoch_action=2.0, layer_action_value=3 -> shared_params=3, loss=0.0003, acc=1.0000, used=10388, eff_epochs=2.000
# Client 9: epoch_action=0.1, layer_action_value=3 -> shared_params=3, loss=0.0091, acc=0.9979, used=716, eff_epochs=0.100
# Global-like model test accuracy: 0.0844, loss: 2.6312
# Client 0: test_acc=0.9729, test_loss=0.0900
# Client 1: test_acc=0.9890, test_loss=0.0384
# Client 2: test_acc=0.9850, test_loss=0.0483
# Client 3: test_acc=0.9816, test_loss=0.0586
# Client 4: test_acc=0.9627, test_loss=0.1210
# Client 5: test_acc=0.9731, test_loss=0.0861
# Client 6: test_acc=0.9604, test_loss=0.1244
# Client 7: test_acc=0.9659, test_loss=0.1043
# Client 8: test_acc=0.9886, test_loss=0.0367
# Client 9: test_acc=0.9816, test_loss=0.0598
# Average client test accuracy: 0.9761, Average client test loss: 0.0768
# Client 0: reward=-3.0240 (local_acc=1.0000, cap=0.50, shared_dist=0.0240, epoch_req=5.000, comp_penalty=4.5000, shared_layers=3, pref_layers=3, exceed_layers=0, comm_penalty=0.0000)
# Client 1: reward=0.4960 (local_acc=1.0000, cap=0.01, shared_dist=0.0240, epoch_req=0.500, comp_penalty=0.4900, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# Client 2: reward=-2.0240 (local_acc=1.0000, cap=1.00, shared_dist=0.0240, epoch_req=0.100, comp_penalty=0.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 3: reward=2.9692 (local_acc=1.0000, cap=2.00, shared_dist=0.0308, epoch_req=0.500, comp_penalty=0.0000, shared_layers=1, pref_layers=2, exceed_layers=0, comm_penalty=0.0000)
# Client 4: reward=2.9760 (local_acc=1.0000, cap=2.00, shared_dist=0.0240, epoch_req=2.000, comp_penalty=0.0000, shared_layers=3, pref_layers=4, exceed_layers=0, comm_penalty=0.0000)
# Client 5: reward=1.4760 (local_acc=1.0000, cap=0.50, shared_dist=0.0240, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 6: reward=-2.0240 (local_acc=1.0000, cap=1.00, shared_dist=0.0240, epoch_req=1.000, comp_penalty=0.0000, shared_layers=3, pref_layers=1, exceed_layers=2, comm_penalty=4.0000)
# Client 7: reward=2.9760 (local_acc=1.0000, cap=2.00, shared_dist=0.0240, epoch_req=0.500, comp_penalty=0.0000, shared_layers=3, pref_layers=6, exceed_layers=0, comm_penalty=0.0000)
# Client 8: reward=-2.8240 (local_acc=1.0000, cap=0.10, shared_dist=0.0240, epoch_req=2.000, comp_penalty=1.9000, shared_layers=3, pref_layers=2, exceed_layers=1, comm_penalty=2.0000)
# Client 9: reward=5.9740 (local_acc=0.9979, cap=5.00, shared_dist=0.0240, epoch_req=0.100, comp_penalty=0.0000, shared_layers=3, pref_layers=5, exceed_layers=0, comm_penalty=0.0000)
# RL loss: 0.1116

# %% [markdown]
# # Save logs to CSV

# %%
global_df   = pd.DataFrame(global_log)
client_df   = pd.DataFrame(client_log)
distance_df = pd.DataFrame(distance_log)

prefix = "NEW_2_2D_MNIST_ALPHA_1_RESNET18_PFL_RL"

global_path   = os.path.join(LOG_DIR, f"{prefix}_global_log.csv")
client_path   = os.path.join(LOG_DIR, f"{prefix}_client_log.csv")
distance_path = os.path.join(LOG_DIR, f"{prefix}_distance_log.csv")

global_df.to_csv(global_path, index=False)
client_df.to_csv(client_path, index=False)
distance_df.to_csv(distance_path, index=False)

print("Saved:")
print("  ", global_path)
print("  ", client_path)
print("  ", distance_path)
# Out:
# Saved:
#    /content/drive/MyDrive/FL_59500_RL_Logs/NEW_2_2D_MNIST_ALPHA_1_RESNET18_PFL_RL_global_log.csv
#    /content/drive/MyDrive/FL_59500_RL_Logs/NEW_2_2D_MNIST_ALPHA_1_RESNET18_PFL_RL_client_log.csv
#    /content/drive/MyDrive/FL_59500_RL_Logs/NEW_2_2D_MNIST_ALPHA_1_RESNET18_PFL_RL_distance_log.csv
